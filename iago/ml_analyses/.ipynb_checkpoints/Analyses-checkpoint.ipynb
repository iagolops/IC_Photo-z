# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
column_names = ['ztrue','zmode0','zmean1','zConf0','zConf1','err0','err1']
df = pd.read_csv('/home/iago.dias/MLZ/mlz/test/results/DES_VIPERS.results.0.mlz',names = column_names, header = None, skiprows =1, sep =' ')

# %%
len(df)
# Out:
# 17220

# %%
df = df[df['err0']<1]
len(df)
# Out:
# 17220

# %%
diff = df['ztrue']- df['zmode0']

# %%
plt.scatter(df['ztrue'],diff,color = 'green', s=0.3)
plt.xlim(0.25,1.25)
plt.ylim(-0.5,0.5)
# Out:
# (-0.5, 0.5)
