# %%
from dblinea import DBBase
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm
import os
from astroquery.vizier import Vizier
import astropy.coordinates as coord
import astropy.units as u
from astropy.coordinates import SkyCoord
from astropy.io import ascii

# %% [markdown]
# ## Selecting SDSS/BOSS cross-matched

# %%
sdss = pd.read_csv('/home/iago.dias/SDSS-BOSS.csv')

# %%
sdss = sdss[['RA_ICRS','DE_ICRS','zsp']]
sdss.columns = ['ra','dec','z']

# %%
sdss['survey']='SDSS/BOSS'

# %%
sdss = sdss[(sdss['ra']>35) & (sdss['ra']<37.5) & (sdss['dec']<-3.5)& (sdss['dec']>-5.7)]

# %%
sdss
# Out:
#              ra       dec        z     survey
# 229   37.255031 -5.688772  0.95767  SDSS/BOSS
# 237   37.290464 -5.670331  0.33875  SDSS/BOSS
# 238   37.437218 -5.675375  0.48237  SDSS/BOSS
# 239   37.413628 -5.640567  0.08701  SDSS/BOSS
# 240   37.390754 -5.624758  0.98790  SDSS/BOSS
# ...         ...       ...      ...        ...
# 1712  35.285733 -3.539826  0.57483  SDSS/BOSS
# 1713  35.278646 -3.524045  0.55166  SDSS/BOSS
# 1715  35.510182 -3.567297  0.43385  SDSS/BOSS
# 1724  35.814534 -3.506449  0.61090  SDSS/BOSS
# 1880  35.131484 -3.598156  0.57698  SDSS/BOSS
#
# [859 rows x 4 columns]

# %%
xlim = [35, 37.6]
ylim = [-5.7, -3.5]
l = 750000
query = f"SELECT alphawin_j2000, deltawin_j2000,ra,dec, extended_class_coadd, mag_auto_g, mag_auto_r,mag_auto_i,mag_auto_z,mag_auto_y, magerr_auto_g, magerr_auto_r, magerr_auto_i, magerr_auto_z, magerr_auto_y FROM des_dr2.coadd_objects WHERE q3c_poly_query(ra, dec, ARRAY[{xlim[0]}, {ylim[1]}, {xlim[0]}, {ylim[0]}, {xlim[1]}, {ylim[0]}, {xlim[1]}, {ylim[1]}]) AND extended_class_coadd >= 2 AND magerr_auto_g<0.103 AND magerr_auto_r<0.103 AND magerr_auto_i<0.103 AND magerr_auto_z<0.103 AND magerr_auto_y<0.103 limit {l}"

# %%
# %%time
df_phot = db.fetchall_df(query)
df_phot
# Out:
# CPU times: user 1.02 s, sys: 204 ms, total: 1.22 s
# Wall time: 22.4 s
#        alphawin_j2000  deltawin_j2000         ra       dec
# 0           35.005503       -5.688872  35.005503 -5.688872  \
# 1           35.031574       -5.689481  35.031574 -5.689481
# 2           35.010391       -5.670947  35.010391 -5.670947
# 3           35.039066       -5.698757  35.039066 -5.698757
# 4           35.061793       -5.689300  35.061793 -5.689300
# ...               ...             ...        ...       ...
# 32750       37.588446       -3.534197  37.588446 -3.534197
# 32751       37.597248       -3.526561  37.597248 -3.526561
# 32752       37.598168       -3.522244  37.598168 -3.522244
# 32753       37.585354       -3.507976  37.585354 -3.507976
# 32754       37.599093       -3.512776  37.599093 -3.512776
#
#        extended_class_coadd  mag_auto_g  mag_auto_r  mag_auto_i  mag_auto_z
# 0                         3   21.958111   20.981462   20.643782   20.458216  \
# 1                         3   20.776588   20.371265   20.171185   20.133593
# 2                         3   22.891459   21.160873   20.222704   19.779186
# 3                         3   21.094006   20.091734   19.822252   19.606539
# 4                         3   23.059689   21.421265   20.365311   19.924723
# ...                     ...         ...         ...         ...         ...
# 32750                     3   22.306887   20.539705   19.866030   19.536564
# 32751                     3   22.627661   21.055880   20.420755   20.173534
# 32752                     3   21.260717   20.547453   20.317461   20.064272
# 32753                     3   22.302099   20.609623   20.093550   19.731237
# 32754                     3   22.987028   21.334810   20.564507   20.187857
#
#        mag_auto_y  magerr_auto_g  magerr_auto_r  magerr_auto_i  magerr_auto_z
# 0       20.421747       0.026951       0.014084       0.017568       0.027348  \
# 1       20.193224       0.008345       0.007400       0.010368       0.018325
# 2       19.534164       0.058485       0.015463       0.010934       0.015598
# 3       19.474741       0.016560       0.008578       0.010680       0.017980
# 4       19.777346       0.075621       0.021857       0.014157       0.017514
# ...           ...            ...            ...            ...            ...
# 32750   19.406834       0.043240       0.011027       0.010970       0.015444
# 32751   20.031332       0.047657       0.014732       0.015150       0.023057
# 32752   19.966024       0.016808       0.011510       0.017221       0.024059
# 32753   19.647053       0.051195       0.014470       0.017434       0.021965
# 32754   20.096292       0.059058       0.017016       0.016643       0.020837
#
#        magerr_auto_y
# 0           0.089213
# 1           0.066866
# 2           0.037691
# 3           0.049160
# 4           0.052168
# ...              ...
# 32750       0.041117
# 32751       0.060116
# 32752       0.069530
# 32753       0.064953
# 32754       0.060350
#
# [32755 rows x 15 columns]

# %%
# %%time
coords1 = SkyCoord(ra=df_phot['ra'], dec=df_phot['dec'], unit=(u.deg, u.deg))
coords2 = SkyCoord(ra=sdss['ra'], dec=sdss['dec'], unit=(u.deg, u.deg))
# Out:
# CPU times: user 4.71 s, sys: 19.1 ms, total: 4.73 s
# Wall time: 4.73 s

# %%
# Defina um raio de busca (por exemplo, 1 arcsec)
radius = 1 * u.arcsec

# Realize o cruzamento entre os catálogos
# use o método search_around_sky para encontrar objetos coincidentes em um raio
idx1, idx2, d2d, _ = coords1.search_around_sky(coords2, radius)

# idx1 e idx2 contêm os índices dos objetos correspondentes em catalog1 e catalog2
# d2d contém as distâncias angulares entre os objetos correspondentes em arcsec

# Agora você pode usar os índices para acessar os objetos correspondentes em seus catálogos originais
sdss_matched = df_phot.iloc[idx2]
zspec = sdss.iloc[idx1]['z'].values

sdss_matched['z'] = zspec
# Out:
# /tmp/ipykernel_2134/4229036883.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdss_matched['z'] = zspec

# %%
sdss_matched['survey']='SDSS/BOSS'
# Out:
# /tmp/ipykernel_2134/249163995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdss_matched['survey']='SDSS/BOSS'

# %%
sdss_matched
# Out:
#        alphawin_j2000  deltawin_j2000         ra       dec
# 24594       37.290511       -5.670288  37.290511 -5.670288  \
# 23889       37.437240       -5.675342  37.437240 -5.675342
# 24742       37.413654       -5.640530  37.413654 -5.640530
# 24548       37.219842       -5.677816  37.219842 -5.677816
# 24118       37.122262       -5.675978  37.122262 -5.675978
# ...               ...             ...        ...       ...
# 17716       35.285689       -3.539843  35.285689 -3.539843
# 17724       35.278654       -3.524113  35.278654 -3.524113
# 17843       35.510185       -3.567325  35.510185 -3.567325
# 23272       35.814469       -3.506495  35.814469 -3.506495
# 17510       35.131505       -3.598207  35.131505 -3.598207
#
#        extended_class_coadd  mag_auto_g  mag_auto_r  mag_auto_i  mag_auto_z
# 24594                     3   20.368042   18.719124   18.175367   17.871948  \
# 23889                     3   21.848080   20.027540   19.321104   18.867994
# 24742                     3   17.227966   16.316692   15.940803   15.656432
# 24548                     3   20.389721   18.815584   18.272215   17.940228
# 24118                     3   21.013559   19.355232   18.765299   18.436386
# ...                     ...         ...         ...         ...         ...
# 17716                     3   21.766348   20.213488   19.387247   18.973791
# 17724                     3   21.742535   19.765615   18.933088   18.531687
# 17843                     3   21.693323   20.039982   19.464895   19.154772
# 23272                     3   22.180002   20.395002   19.347071   18.906082
# 17510                     3   22.132837   20.415741   19.577312   19.251131
#
#        mag_auto_y  magerr_auto_g  magerr_auto_r  magerr_auto_i  magerr_auto_z
# 24594   17.735844       0.012804       0.003618       0.003889       0.005722  \
# 23889   18.668270       0.040691       0.009449       0.009188       0.012096
# 24742   15.529766       0.001460       0.000828       0.001053       0.001519
# 24548   17.810299       0.009818       0.003106       0.003295       0.004647
# 24118   18.270586       0.029352       0.007962       0.008113       0.011619
# ...           ...            ...            ...            ...            ...
# 17716   18.866899       0.029791       0.010394       0.008991       0.011265
# 17724   18.472466       0.032502       0.007749       0.006445       0.007658
# 17843   19.030590       0.029494       0.009056       0.009120       0.012940
# 23272   18.829689       0.057846       0.016076       0.010689       0.012002
# 17510   19.132896       0.040320       0.011773       0.009506       0.013352
#
#        magerr_auto_y        z     survey
# 24594       0.016731  0.33875  SDSS/BOSS
# 23889       0.032901  0.48237  SDSS/BOSS
# 24742       0.004480  0.08701  SDSS/BOSS
# 24548       0.013845  0.29940  SDSS/BOSS
# 24118       0.026204  0.33747  SDSS/BOSS
# ...              ...      ...        ...
# 17716       0.030233  0.57483  SDSS/BOSS
# 17724       0.021189  0.55166  SDSS/BOSS
# 17843       0.030145  0.43385  SDSS/BOSS
# 23272       0.029610  0.61090  SDSS/BOSS
# 17510       0.033022  0.57698  SDSS/BOSS
#
# [662 rows x 17 columns]

# %% [markdown]
# ## Selecting 2dFRGS cross-matched

# %%
two_d = pd.read_csv('/home/iago.dias/2dfgrs.csv')

# %%
two_d = two_d[['RAJ2000','DEJ2000','z']]
two_d.columns=['ra','dec','z']

# %%
two_d['survey']='2dFRGS'

# %%
two_d = two_d[(two_d['ra']>51.5) & (two_d['ra']<53.9) & (two_d['dec']<-26.9)& (two_d['dec']>-29.2)]

# %%
two_d
# Out:
#              ra        dec       z  survey
# 890   52.400792 -29.166583  0.2360  2dFRGS
# 891   52.488417 -29.188250  0.0715  2dFRGS
# 892   52.522583 -29.162500  0.2830  2dFRGS
# 893   52.489458 -29.095500  0.1101  2dFRGS
# 894   52.453292 -29.074472  0.0712  2dFRGS
# ...         ...        ...     ...     ...
# 2736  51.899750 -26.946694  0.1489  2dFRGS
# 2737  51.736708 -26.951944  0.1438  2dFRGS
# 2738  51.721333 -26.928528  0.1433  2dFRGS
# 2740  51.819292 -26.903333  0.2023  2dFRGS
# 2752  52.401250 -26.921694  0.1033  2dFRGS
#
# [739 rows x 4 columns]

# %%
xlim = [51.5, 53.9]
ylim = [-29.2, -26.9]
l = 750000
query = f"SELECT alphawin_j2000, deltawin_j2000,ra,dec, extended_class_coadd, mag_auto_g, mag_auto_r,mag_auto_i,mag_auto_z,mag_auto_y, magerr_auto_g, magerr_auto_r, magerr_auto_i, magerr_auto_z, magerr_auto_y FROM des_dr2.coadd_objects WHERE q3c_poly_query(ra, dec, ARRAY[{xlim[0]}, {ylim[1]}, {xlim[0]}, {ylim[0]}, {xlim[1]}, {ylim[0]}, {xlim[1]}, {ylim[1]}]) AND extended_class_coadd >= 2 AND magerr_auto_g<0.103 AND magerr_auto_r<0.103 AND magerr_auto_i<0.103 AND magerr_auto_z<0.103 AND magerr_auto_y<0.103 limit {l}"

# %%
# %%time
df_phot_2 = db.fetchall_df(query)
df_phot_2
# Out:
# CPU times: user 300 ms, sys: 70.3 ms, total: 371 ms
# Wall time: 19.8 s
#        alphawin_j2000  deltawin_j2000         ra        dec
# 0           51.506018      -29.184583  51.506018 -29.184583  \
# 1           51.505888      -29.183657  51.505888 -29.183657
# 2           51.502942      -29.174631  51.502942 -29.174631
# 3           51.517326      -29.172725  51.517326 -29.172725
# 4           51.501859      -29.158987  51.501859 -29.158987
# ...               ...             ...        ...        ...
# 21036       53.798424      -26.904304  53.798424 -26.904304
# 21037       53.849126      -26.912939  53.849126 -26.912939
# 21038       53.879422      -26.930654  53.879422 -26.930654
# 21039       53.876300      -26.904642  53.876300 -26.904642
# 21040       53.882221      -26.901286  53.882221 -26.901286
#
#        extended_class_coadd  mag_auto_g  mag_auto_r  mag_auto_i  mag_auto_z
# 0                         3   20.611647   19.047203   18.492163   18.176331  \
# 1                         3   21.521557   19.970804   19.470030   19.145790
# 2                         3   22.575340   21.575972   20.843239   20.542154
# 3                         3   22.461243   20.969349   20.427479   20.109015
# 4                         3   19.863054   18.898100   18.541859   18.235250
# ...                     ...         ...         ...         ...         ...
# 21036                     3   15.354554   16.414850   16.621065   16.224180
# 21037                     3   21.035069   20.062515   19.646963   19.419521
# 21038                     3   22.657209   20.719599   19.791544   19.403477
# 21039                     3   22.730743   21.455261   20.919239   20.539339
# 21040                     3   22.007765   20.779320   20.165056   19.735243
#
#        mag_auto_y  magerr_auto_g  magerr_auto_r  magerr_auto_i  magerr_auto_z
# 0       17.990538       0.012185       0.003712       0.003734       0.006877  \
# 1       19.012835       0.018513       0.005605       0.005875       0.010924
# 2       20.297100       0.049666       0.023649       0.021198       0.042151
# 3       19.945820       0.040316       0.013854       0.015255       0.022772
# 4       18.258886       0.005854       0.003055       0.003547       0.007010
# ...           ...            ...            ...            ...            ...
# 21036   14.349154       0.000335       0.000812       0.001952       0.002531
# 21037   19.347204       0.012715       0.006460       0.009361       0.014374
# 21038   19.343946       0.047850       0.010627       0.009254       0.012288
# 21039   20.258663       0.050105       0.019516       0.025348       0.034028
# 21040   19.625706       0.026959       0.010820       0.013243       0.016497
#
#        magerr_auto_y
# 0           0.017213
# 1           0.028689
# 2           0.087047
# 3           0.066777
# 4           0.019434
# ...              ...
# 21036       0.001309
# 21037       0.041460
# 21038       0.039295
# 21039       0.082110
# 21040       0.047786
#
# [21041 rows x 15 columns]

# %%
# %%time
coords1 = SkyCoord(ra=df_phot_2['ra'], dec=df_phot_2['dec'], unit=(u.deg, u.deg))
coords2 = SkyCoord(ra=two_d['ra'], dec=two_d['dec'], unit=(u.deg, u.deg))
# Out:
# CPU times: user 3.13 s, sys: 13.3 ms, total: 3.14 s
# Wall time: 3.14 s

# %%
# Defina um raio de busca (por exemplo, 1 arcsec)
radius = 1 * u.arcsec

# Realize o cruzamento entre os catálogos
# use o método search_around_sky para encontrar objetos coincidentes em um raio
idx1, idx2, d2d, _ = coords1.search_around_sky(coords2, radius)

# idx1 e idx2 contêm os índices dos objetos correspondentes em catalog1 e catalog2
# d2d contém as distâncias angulares entre os objetos correspondentes em arcsec

# Agora você pode usar os índices para acessar os objetos correspondentes em seus catálogos originais
two_d_matched = df_phot_2.iloc[idx2]
zspec = two_d.iloc[idx1]['z'].values

two_d_matched['z'] = zspec
# Out:
# /tmp/ipykernel_2134/1018296563.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   two_d_matched['z'] = zspec

# %%
two_d_matched['survey']='2dFRGS'
# Out:
# /tmp/ipykernel_2134/2531596005.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   two_d_matched['survey']='2dFRGS'

# %%
two_d_matched
# Out:
#        alphawin_j2000  deltawin_j2000         ra        dec
# 432         51.730250      -29.159197  51.730250 -29.159197  \
# 480         51.783576      -29.093342  51.783576 -29.093342
# 446         51.726861      -29.100389  51.726861 -29.100389
# 385         51.696841      -29.006400  51.696841 -29.006400
# 2046        52.054073      -29.175033  52.054073 -29.175033
# ...               ...             ...        ...        ...
# 11778       51.869277      -27.038115  51.869277 -27.038115
# 11932       51.899973      -26.946502  51.899973 -26.946502
# 11841       51.736952      -26.951882  51.736952 -26.951882
# 11836       51.721499      -26.928319  51.721499 -26.928319
# 11874       51.819520      -26.903164  51.819520 -26.903164
#
#        extended_class_coadd  mag_auto_g  mag_auto_r  mag_auto_i  mag_auto_z
# 432                       3   18.890404   17.888821   17.488638   17.207067  \
# 480                       3   18.610512   18.239779   18.096523   17.995811
# 446                       3   18.832258   17.866297   17.469213   17.193844
# 385                       3   18.454252   17.520678   17.126947   16.858967
# 2046                      3   17.887152   16.835957   16.419085   16.104586
# ...                     ...         ...         ...         ...         ...
# 11778                     3   18.216961   17.561947   17.258505   17.113890
# 11932                     3   18.075142   17.309658   16.954515   16.730850
# 11841                     3   18.326010   17.501541   17.155703   16.918789
# 11836                     3   17.356909   16.349276   15.953111   15.670392
# 11874                     3   18.150614   17.419329   16.953358   16.520401
#
#        mag_auto_y  magerr_auto_g  magerr_auto_r  magerr_auto_i  magerr_auto_z
# 432     17.112206       0.002955       0.001547       0.001848       0.003098  \
# 480     17.939417       0.004122       0.003969       0.006020       0.011065
# 446     17.095108       0.002278       0.001203       0.001443       0.002203
# 385     16.742199       0.002345       0.001446       0.001760       0.002409
# 2046    16.013882       0.002141       0.001120       0.001353       0.001739
# ...           ...            ...            ...            ...            ...
# 11778   17.061022       0.002204       0.001572       0.001899       0.003314
# 11932   16.650419       0.001843       0.001228       0.001490       0.002580
# 11841   16.844782       0.002434       0.001458       0.001655       0.002651
# 11836   15.569478       0.001637       0.000858       0.000930       0.001556
# 11874   15.955475       0.002787       0.001794       0.002039       0.002799
#
#        magerr_auto_y       z  survey
# 432         0.008942  0.1348  2dFRGS
# 480         0.035734  0.0078  2dFRGS
# 446         0.005988  0.1168  2dFRGS
# 385         0.008960  0.1104  2dFRGS
# 2046        0.006322  0.1353  2dFRGS
# ...              ...     ...     ...
# 11778       0.011871  0.2210  2dFRGS
# 11932       0.009367  0.1489  2dFRGS
# 11841       0.010985  0.1438  2dFRGS
# 11836       0.005874  0.1433  2dFRGS
# 11874       0.006207  0.2023  2dFRGS
#
# [490 rows x 17 columns]

# %% [markdown]
# ## Selecting OzDES cross-match

# %%
ozdes = pd.read_csv('/home/iago.dias/OzDES.csv')

# %%
ozdes = ozdes[ozdes['types']=='Photo-z']

# %%
ozdes = ozdes[['RAJ2000','DEJ2000','z']]
ozdes.columns = ['ra','dec','z']

# %%
ozdes['survey']='OzDES'

# %%
ozdes = ozdes[(ozdes['ra']>51.5) & (ozdes['ra']<53.9) & (ozdes['dec']<-26.9)& (ozdes['dec']>-29.2)]

# %%
ozdes
# Out:
#              ra        dec        z survey
# 663   52.364000 -29.063611  0.29499  OzDES
# 665   52.346208 -29.047444  0.46218  OzDES
# 666   52.396083 -29.010444  0.21749  OzDES
# 670   52.340125 -29.003250  0.68351  OzDES
# 671   52.352750 -28.996944  0.40005  OzDES
# ...         ...        ...      ...    ...
# 5352  53.552708 -27.018139  0.63642  OzDES
# 5366  53.478083 -26.959389  0.25218  OzDES
# 5377  53.263625 -27.083000  0.62159  OzDES
# 5423  53.811417 -26.921611  0.71457  OzDES
# 5425  53.757333 -26.913694  0.62488  OzDES
#
# [775 rows x 4 columns]

# %%
# %%time
coords1 = SkyCoord(ra=df_phot_2['ra'], dec=df_phot_2['dec'], unit=(u.deg, u.deg))
coords2 = SkyCoord(ra=ozdes['ra'], dec=ozdes['dec'], unit=(u.deg, u.deg))
# Out:
# CPU times: user 3.67 s, sys: 50.5 ms, total: 3.72 s
# Wall time: 3.72 s

# %%
# Defina um raio de busca (por exemplo, 1 arcsec)
radius = 1 * u.arcsec

# Realize o cruzamento entre os catálogos
# use o método search_around_sky para encontrar objetos coincidentes em um raio
idx1, idx2, d2d, _ = coords1.search_around_sky(coords2, radius)

# idx1 e idx2 contêm os índices dos objetos correspondentes em catalog1 e catalog2
# d2d contém as distâncias angulares entre os objetos correspondentes em arcsec

# Agora você pode usar os índices para acessar os objetos correspondentes em seus catálogos originais
ozdes_matched = df_phot_2.iloc[idx2]
zspec = ozdes.iloc[idx1]['z'].values

ozdes_matched['z'] = zspec
# Out:
# /tmp/ipykernel_2134/2744309778.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ozdes_matched['z'] = zspec

# %%
ozdes_matched['survey']='OzDES'
# Out:
# /tmp/ipykernel_2134/587646815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ozdes_matched['survey']='OzDES'

# %%
ozdes_matched
# Out:
#        alphawin_j2000  deltawin_j2000         ra        dec
# 2681        52.346351      -29.047413  52.346351 -29.047413  \
# 2723        52.396158      -29.010452  52.396158 -29.010452
# 2718        52.352790      -28.996953  52.352790 -28.996953
# 2829        52.326229      -28.956228  52.326229 -28.956228
# 2643        52.245945      -28.850635  52.245945 -28.850635
# ...               ...             ...        ...        ...
# 20476       53.552743      -27.018133  53.552743 -27.018133
# 20471       53.478112      -26.959408  53.478112 -26.959408
# 20007       53.263696      -27.083038  53.263696 -27.083038
# 20998       53.811449      -26.921607  53.811449 -26.921607
# 20975       53.757341      -26.913703  53.757341 -26.913703
#
#        extended_class_coadd  mag_auto_g  mag_auto_r  mag_auto_i  mag_auto_z
# 2681                      3   21.291992   20.458984   20.158737   19.824772  \
# 2723                      3   20.931192   19.781029   19.302427   18.987013
# 2718                      3   20.323170   19.225962   18.853956   18.548046
# 2829                      3   22.000790   20.638786   20.138409   19.833902
# 2643                      3   20.797237   19.957933   19.755501   19.529701
# ...                     ...         ...         ...         ...         ...
# 20476                     3   22.247082   21.135773   20.502247   20.208508
# 20471                     3   21.351858   20.625410   20.324642   20.132301
# 20007                     3   21.876299   20.946074   20.394661   20.108767
# 20998                     3   23.602448   21.813089   20.773027   20.346767
# 20975                     3   21.757795   20.856041   20.409985   20.185291
#
#        mag_auto_y  magerr_auto_g  magerr_auto_r  magerr_auto_i  magerr_auto_z
# 2681    19.539526       0.017564       0.010883       0.014796       0.020341  \
# 2723    18.862089       0.016878       0.008097       0.009133       0.013398
# 2718    18.512770       0.008102       0.003936       0.004942       0.006943
# 2829    19.590752       0.026301       0.009962       0.012177       0.016120
# 2643    19.501705       0.010183       0.006716       0.009377       0.013478
# ...           ...            ...            ...            ...            ...
# 20476   20.062546       0.035119       0.018320       0.019038       0.025469
# 20471   20.138453       0.013876       0.008920       0.012771       0.020135
# 20007   19.970228       0.035056       0.019135       0.022514       0.031080
# 20998   20.302980       0.095374       0.024161       0.018833       0.024319
# 20975   20.086878       0.030883       0.016627       0.024527       0.036799
#
#        magerr_auto_y        z survey
# 2681        0.056159  0.46218  OzDES
# 2723        0.040550  0.21749  OzDES
# 2718        0.025024  0.40005  OzDES
# 2829        0.049998  0.43263  OzDES
# 2643        0.050321  0.43174  OzDES
# ...              ...      ...    ...
# 20476       0.080495  0.63642  OzDES
# 20471       0.069047  0.25218  OzDES
# 20007       0.098951  0.62159  OzDES
# 20998       0.078899  0.71457  OzDES
# 20975       0.102547  0.62488  OzDES
#
# [561 rows x 17 columns]

# %% [markdown]
# ## Selecting VVDS, ZCOSMOS AND ACES

# %%
db=DBBase()

# %% [markdown]
# ```sql
# SELECT *
# FROM des_dr2.public_specz_compilation
# WHERE survey = 'VVDS' OR survey = 'ZCOSMOS' OR survey = 'ACES'
#
# ```

# %%
query_spec = "SELECT * FROM des_dr2.public_specz_compilation WHERE survey = 'VVDS' OR survey = 'ZCOSMOS' OR survey = 'ACES'"

# %%
df_spec = db.fetchall_df(query_spec)

# %%
df_spec
# Out:
#                ra        dec         z      err_z  flag_des   survey
# 0       53.001330 -27.904486  0.619827   0.000152         3     ACES  \
# 1       53.237947 -27.967360  0.355152   0.000009         4     ACES
# 2       52.977095 -27.869796  0.863873   0.000146         3     ACES
# 3       52.981518 -27.870166  0.645545   0.000080         4     ACES
# 4       52.847088 -27.818247  0.966832   0.000233         3     ACES
# ...           ...        ...       ...        ...       ...      ...
# 30327  149.697571   1.895577  0.775600  99.000000         4  ZCOSMOS
# 30328  149.700623   1.885304  0.479600  99.000000         4  ZCOSMOS
# 30329  149.687683   1.899736  0.164700  99.000000         4  ZCOSMOS
# 30330  149.679794   1.898666  0.361000  99.000000         4  ZCOSMOS
# 30331  149.657318   1.929966  0.475700  99.000000         4  ZCOSMOS
#
#        flag_survey  id_spec
# 0              3.0     9999
# 1              4.0     9999
# 2              3.0     9999
# 3              4.0     9999
# 4              3.0     9999
# ...            ...      ...
# 30327          3.0     9999
# 30328          3.0     9999
# 30329          3.0     9999
# 30330          3.0     9999
# 30331          4.0     9999
#
# [30332 rows x 8 columns]

# %%
zcosmos=df_spec[df_spec['survey']=='ZCOSMOS']
aces=df_spec[df_spec['survey']=='ACES']
vvds=df_spec[df_spec['survey']=='VVDS']

# %%
plt.scatter(aces['ra'],aces['dec'],color='blue')
plt.scatter(vvds['ra'],vvds['dec'],color='red',s=0.5)
plt.scatter(zcosmos['ra'],zcosmos['dec'],color='orange')
#plt.xlim(51,54)
#plt.ylim(-30,-27)

# %% [markdown]
# ## Selecting VVDS, ACES AND ZCOSMOS cross-matched

# %% [markdown]
# ```sql
# SELECT *
# FROM des_dr2.public_pz_training_set
# WHERE survey = 'VVDS' OR survey = 'ZCOSMOS' OR survey = 'ACES'
# ```

# %%
query_matched = "SELECT * FROM des_dr2.public_pz_training_set WHERE survey = 'VVDS' OR survey = 'ZCOSMOS' OR survey = 'ACES' AND magerr_auto_g<0.103 AND magerr_auto_r<0.103 AND magerr_auto_i<0.103 AND magerr_auto_z<0.103 AND magerr_auto_y<0.103"

# %%
df_matched = db.fetchall_df(query_matched)

# %%
df_matched.columns=['coadd_object_id','ra','dec','z','err_z','flag_des','survey','flag','mag_auto_g','mag_auto_r','mag_auto_i','mag_auto_z','mag_auto_y','magerr_auto_g','magerr_auto_r','magerr_auto_i','magerr_auto_z','magerr_auto_y']

# %%
zcosmos_matched = df_matched[df_matched['survey']=='ZCOSMOS']
aces_matched = df_matched[df_matched['survey']=='ACES']
vvds_matched = df_matched[df_matched['survey']=='VVDS']

# %% [markdown]
# ## Main training sample

# %%
vvds_deep = vvds_matched[(vvds_matched['ra']>35) & (vvds_matched['ra']<38)] #Não é necessário especificar o dec
training_1 = vvds_deep.sample(int(len(vvds_deep)/2)) #selecting half of the catalogue
training_2 = sdss_matched.sample(int(len(sdss_matched)/2)) 
training_3 = aces_matched.sample(int(len(aces_matched)/2))
training_4 = two_d_matched.sample(int(len(two_d_matched)/2))
training_5 = ozdes_matched.sample(int(len(ozdes_matched)/2))

# %%
print(len(vvds_deep))
print(len(sdss_matched))
print(len(aces_matched))
print(len(two_d_matched))
print(len(ozdes_matched))
# Out:
# 4814
# 662
# 591
# 490
# 561

# %%
training = pd.concat([training_1,training_2,training_3,training_4,training_5],axis=0)

# %%
training
# Out:
#        coadd_object_id         ra        dec        z  err_z  flag_des survey
# 5594      1.278928e+09  36.739842  -4.346460  0.40950   99.0       4.0   VVDS  \
# 5044      1.278934e+09  36.415750  -4.411177  0.58410   99.0       3.0   VVDS
# 8695      1.278941e+09  36.904207  -4.494045  0.63170   99.0       3.0   VVDS
# 5923      1.273509e+09  36.279772  -4.586562  0.55290   99.0       3.0   VVDS
# 5280      1.278917e+09  36.651119  -4.218535  1.27250   99.0       3.0   VVDS
# ...                ...        ...        ...      ...    ...       ...    ...
# 16720              NaN  53.371861 -28.224856  0.53717    NaN       NaN  OzDES
# 14714              NaN  53.443723 -29.129739  0.24173    NaN       NaN  OzDES
# 8943               NaN  52.876733 -28.347851  0.57908    NaN       NaN  OzDES
# 18154              NaN  53.778325 -27.920227  0.59860    NaN       NaN  OzDES
# 6437               NaN  51.833046 -27.634693  0.36877    NaN       NaN  OzDES
#
#        flag  mag_auto_g  mag_auto_r  ...  mag_auto_z  mag_auto_y
# 5594    4.0   23.436403   22.566639  ...   22.257919   22.658794  \
# 5044    3.0   23.268129   22.565674  ...   22.228621   22.198723
# 8695    3.0   24.157528   23.405409  ...   22.479637   22.281464
# 5923    3.0   24.455967   23.926434  ...   23.311817   23.589973
# 5280    3.0   25.065823   24.805550  ...   23.885391   24.063066
# ...     ...         ...         ...  ...         ...         ...
# 16720   NaN   22.550819   21.170971  ...   20.169495   20.145475
# 14714   NaN   20.024294   18.810007  ...   18.020788   17.894243
# 8943    NaN   22.427803   20.519289  ...   19.261681   19.172321
# 18154   NaN   23.554937   21.636402  ...   20.227556   20.028954
# 6437    NaN   22.098558   20.646618  ...   19.767962   19.679226
#
#        magerr_auto_g  magerr_auto_r  magerr_auto_i  magerr_auto_z
# 5594        0.073207       0.040528       0.075485       0.119339  \
# 5044        0.081065       0.055433       0.074086       0.138044
# 8695        0.161953       0.089834       0.089109       0.134666
# 5923        0.157059       0.119507       0.307841       0.226544
# 5280        0.225470       0.229955       0.327262       0.361583
# ...              ...            ...            ...            ...
# 16720       0.047759       0.018347       0.019333       0.023616
# 14714       0.006677       0.002807       0.003343       0.004410
# 8943        0.062521       0.013557       0.012269       0.013136
# 18154       0.090734       0.020036       0.016775       0.019901
# 6437        0.028504       0.010574       0.010879       0.014678
#
#        magerr_auto_y  alphawin_j2000  deltawin_j2000  extended_class_coadd
# 5594        0.407917             NaN             NaN                   NaN
# 5044        0.316187             NaN             NaN                   NaN
# 8695        0.300914             NaN             NaN                   NaN
# 5923        0.688986             NaN             NaN                   NaN
# 5280        1.161097             NaN             NaN                   NaN
# ...              ...             ...             ...                   ...
# 16720       0.089496       53.371861      -28.224856                   3.0
# 14714       0.016217       53.443723      -29.129739                   3.0
# 8943        0.053096       52.876733      -28.347851                   3.0
# 18154       0.061827       53.778325      -27.920227                   3.0
# 6437        0.051479       51.833046      -27.634693                   3.0
#
# [3558 rows x 21 columns]

# %% [markdown]
# ## Main testing sample

# %%
vvds_snc3 = vvds_matched[(vvds_matched['ra']>51) & (vvds_matched['ra']<54)]
testing_1 = vvds_deep.drop(training_1.index)
testing_2 = sdss_matched.drop(training_2.index)
testing_3 = aces_matched.drop(training_3.index)
testing_4 = two_d_matched.drop(training_4.index)
testing_5 = ozdes_matched.drop(training_5.index)

# %%
testing = pd.concat([vvds_snc3,testing_1,testing_2,testing_3,testing_4,testing_5],axis=0)

# %%
testing
# Out:
#        coadd_object_id         ra        dec        z  err_z  flag_des survey
# 591       1.394581e+09  53.031151 -27.932595  0.68990   99.0       3.0   VVDS  \
# 592       1.394568e+09  53.013513 -27.792171  0.49330   99.0       3.0   VVDS
# 593       1.394566e+09  53.001129 -27.770151  1.03180   99.0       3.0   VVDS
# 594       1.394560e+09  53.039970 -27.711701  0.68260   99.0       4.0   VVDS
# 595       1.394558e+09  53.037355 -27.689939  0.96920   99.0       3.0   VVDS
# ...                ...        ...        ...      ...    ...       ...    ...
# 20804              NaN  53.786211 -27.131339  0.34223    NaN       NaN  OzDES
# 20848              NaN  53.802533 -27.054511  0.19649    NaN       NaN  OzDES
# 20931              NaN  53.832579 -27.041580  0.19722    NaN       NaN  OzDES
# 20476              NaN  53.552743 -27.018133  0.63642    NaN       NaN  OzDES
# 20975              NaN  53.757341 -26.913703  0.62488    NaN       NaN  OzDES
#
#        flag  mag_auto_g  mag_auto_r  ...  mag_auto_z  mag_auto_y
# 591     3.0   23.980019   22.814718  ...   22.239367   21.606356  \
# 592     3.0   24.500084   23.557953  ...   23.435997   99.000000
# 593     3.0   23.792635   23.055094  ...   22.197302   21.712650
# 594     4.0   23.752857   23.197430  ...   22.596949   99.000000
# 595     3.0   24.455936   24.050777  ...   23.096676   22.387093
# ...     ...         ...         ...  ...         ...         ...
# 20804   NaN   21.345751   19.808302  ...   18.941557   18.815334
# 20848   NaN   20.951372   20.273300  ...   19.792761   19.878233
# 20931   NaN   20.214745   19.039188  ...   18.232758   18.132629
# 20476   NaN   22.247082   21.135773  ...   20.208508   20.062546
# 20975   NaN   21.757795   20.856041  ...   20.185291   20.086878
#
#        magerr_auto_g  magerr_auto_r  magerr_auto_i  magerr_auto_z
# 591         0.135014       0.060997       0.096114       0.120197  \
# 592         0.190917       0.113128       0.174226       0.294300
# 593         0.160844       0.098663       0.113951       0.150371
# 594         0.148833       0.116372       0.106797       0.216269
# 595         0.177360       0.161837       0.154889       0.211291
# ...              ...            ...            ...            ...
# 20804       0.019227       0.006251       0.007440       0.009811
# 20848       0.012733       0.008893       0.013739       0.020447
# 20931       0.006637       0.002989       0.003700       0.005173
# 20476       0.035119       0.018320       0.019038       0.025469
# 20975       0.030883       0.016627       0.024527       0.036799
#
#        magerr_auto_y  alphawin_j2000  deltawin_j2000  extended_class_coadd
# 591         0.271189             NaN             NaN                   NaN
# 592        99.000000             NaN             NaN                   NaN
# 593         0.414215             NaN             NaN                   NaN
# 594        99.000000             NaN             NaN                   NaN
# 595         0.479768             NaN             NaN                   NaN
# ...              ...             ...             ...                   ...
# 20804       0.033954       53.786211      -27.131339                   3.0
# 20848       0.084896       53.802533      -27.054511                   3.0
# 20931       0.017261       53.832579      -27.041580                   3.0
# 20476       0.080495       53.552743      -27.018133                   3.0
# 20975       0.102547       53.757341      -26.913703                   3.0
#
# [3767 rows x 21 columns]

# %% [markdown]
# ## Saving data

# %%
del testing['coadd_object_id'], testing['survey'], testing['err_z'], testing['flag'], testing['flag_des'], testing['ra'], testing['dec'], testing['alphawin_j2000'],testing['deltawin_j2000'],testing['extended_class_coadd']
del training['coadd_object_id'], training['survey'], training['err_z'], training['flag'], training['flag_des'], training['ra'], training['dec'], training['alphawin_j2000'],training['deltawin_j2000'],training['extended_class_coadd']

# %%
g = testing['mag_auto_g']
r = testing['mag_auto_r']
i = testing['mag_auto_i']
z = testing['mag_auto_z']
y = testing['mag_auto_y']
gt = training['mag_auto_g']
rt = training['mag_auto_r']
it = training['mag_auto_i']
zt = training['mag_auto_z']
yt = training['mag_auto_y']

testing['g-r'] = g-r
testing['r-i'] = r-i
testing['i-z'] = i-z
testing['z-y'] = z-y
training['g-r'] = gt-rt
training['r-i'] = rt-it
training['i-z'] = it-zt
training['z-y'] = zt-yt

# %%
testing.columns = ['#zs','g','r','i','z','y','eg','er','ei','ez','ey','g-r','r-i','i-z','z-y']
training.columns = ['#zs','g','r','i','z','y','eg','er','ei','ez','ey','g-r','r-i','i-z','z-y']

# %%
testing['eg-r'] = testing['eg']-testing['er']
testing['er-i'] = testing['er']-testing['ei']
testing['ei-z'] = testing['ei']-testing['ez']
testing['ez-y'] = testing['ez']-testing['ey']
training['eg-r'] = training['eg']-training['er']
training['er-i'] = training['er']-training['ei']
training['ei-z'] = training['ei']-training['ez']
training['ez-y'] = training['ez']-training['ey']

# %%
testing.to_csv('/home/iago.dias/Plots-TPZ/iago/ml_analyses/testing.sanchez', sep=' ', index = False)
training.to_csv('/home/iago.dias/Plots-TPZ/iago/ml_analyses/training.sanchez', sep=' ', index = False)

# %% [markdown]
# ## Main sample

# %%
main = pd.concat([testing,training],axis=0)

# %%
main = main[main['z']<1.4]
main = main[main['mag_auto_g_dered']<90]

# %%
r = plt.hist(main['z'], bins = 15)

# %%
t = plt.hist(main['mag_auto_g_dered'], bins =50)
