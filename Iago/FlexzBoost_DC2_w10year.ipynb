# %% [markdown]
# # FlexzBoost on DC2 French

# %% [markdown]
# <span style="font-size:22px;"> Author: Iago Lopes Soares Dias<br>
# Email: iagolops2012@gmail.com</span>

# %% [markdown]
# <span style="font-size:20px;"> The objective of this notebook is to evaluate FlexzBoost on simulated data of LSST, more specifically cosmo DC2 data that came from PZ french group. </span>

# %% [markdown]
# ## Importing packages

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import tables_io
import qp
import sys


from matplotlib import gridspec
import seaborn as sns
from qp.metrics.pit import PIT
from IPython.display import Markdown
import h5py
import os
from qp.ensemble import Ensemble
from qp import interp


from rail.estimation.algos.flexzboost import FlexZBoostInformer, FlexZBoostEstimator
from rail.evaluation.metrics.base import MetricEvaluator
from matplotlib.ticker import FormatStrFormatter
from scipy.stats import gaussian_kde
from rail.core.data import TableHandle, PqHandle, ModelHandle, QPHandle, DataHandle
from rail.core.util_stages import ColumnMapper, TableConverter
from rail.core.data import TableHandle
from rail.core.stage import RailStage
from rail.estimation.algos.naive_stack import NaiveStackSummarizer
from rail.estimation.algos.point_est_hist import PointEstHistSummarizer

import warnings
warnings.filterwarnings("ignore")

# %%
DS = RailStage.data_store
DS.__class__.allow_overwrite = True

# %% [markdown]
# # Selecting the data and analysing

# %% [markdown]
# ## Functions to analyze

# %% [markdown]
# ### plot_errors

# %%
def plot_errors(catalog):
    bands = ['u', 'g', 'r', 'i', 'z', 'y']
    j=1
    plt.figure(figsize=[9,13])
    for i, band in enumerate(bands):

        plt.subplot(3,2,j) 
        mag = np.array(catalog[f'mag_{band}_lsst'])
        err = np.array(catalog[f'mag_err_{band}_lsst'])
        sn = 1/(10**(0.4*err)-1)
        plt.hexbin(mag,sn , None, mincnt=1, cmap='inferno', gridsize=[200,100], bins='log')
        cbar = plt.colorbar()
        plt.ylabel("S/R ", fontsize=13)
        plt.xlabel("mag "+band, fontsize=13)
        plt.ylim(0,100)
        plt.xlim(20,30)
        plt.axhline(10, color= 'red')
        plt.grid(True)
        j+=1
        plt.tight_layout()

# %% [markdown]
# ### mag_histogram

# %%
def mag_histogram(catalog, title='DP0.2'):
    
    bands = ['u','g', 'r', 'i', 'z','y']
    colors = ['blue', 'green', 'orange','red','purple','gray']
    plt.figure(figsize=(9,13))
    bins = np.linspace(9, 37, 57)
    j=1
    for i, (band, color) in enumerate(zip(bands,colors)):
        plt.subplot(3,2,j)
        plt.hist(catalog[f'mag_{band}_lsst'], histtype='stepfilled', bins=bins, label=f'{band} band', alpha = 0.5,
                 edgecolor = "black", color = color)
        #plt.xlim(16,27)
        plt.yscale('log')
        plt.xlabel('mag',fontsize=13)
        plt.ylabel('counts',fontsize=13)
        plt.legend(loc=2)
        plt.grid(True)
        j+=1
    plt.suptitle(title)
    plt.show()

# %% [markdown]
# ### mag_color

# %%
def mag_color(catalog):
    bands = ['u', 'g', 'r', 'i', 'z','y']
    mag_diff = {}
    plt.figure(figsize=(9,13))
    i=1
    for band,_band in zip(bands, bands[1::]):
        plt.subplot(3,2,i)
        i+=1
        mag_diff_v = catalog[f'mag_{band}_lsst']-catalog[f'mag_{_band}_lsst']
        mag_v = catalog[f'mag_{band}_lsst'] 
                   
        plt.hexbin(mag_v, mag_diff_v, None, mincnt=1, cmap='Reds', gridsize=[400,200], bins='log')

        plt.xlabel("mag "+band,fontsize=13)
        plt.ylabel(f"{band}-{_band}",fontsize=13)
        #plt.legend()
        plt.xlim(16,32)
        plt.ylim(-2,5)
        plt.grid(True)
        plt.tight_layout()
    plt.show()

# %% [markdown]
# ### color_color

# %%
def cor_cor(catalog):
    bands = ['u', 'g', 'r', 'i', 'z','y']
    i=1
    plt.figure(figsize=(12,12))
    for index in range(len(bands)-2):
        plt.subplot(3,2,i)
        i+=1
        color = catalog[f'mag_{bands[index+1]}_lsst']
        next_color = catalog[f'mag_{bands[index+2]}_lsst']
        past_color = catalog[f'mag_{bands[index]}_lsst']
        plt.hist2d(past_color-color,color-next_color, bins = 100, cmap='turbo' )
        plt.xlabel(f'{bands[index+1]}-{bands[index+2]}',fontsize=13)
        plt.ylabel(f'{bands[index]}-{bands[index+1]}',fontsize=13)
        #plt.axvline(0)
        #plt.axhline(0)
    plt.show()

# %%
def color_color(catalog):
    bands = ['u', 'g', 'r', 'i', 'z','y']
    i=1
    plt.figure(figsize=(12,12))
    for index in range(len(bands)-2):
        plt.subplot(3,2,i)
        i+=1
        color = catalog[f'mag_{bands[index+1]}_lsst']
        next_color = catalog[f'mag_{bands[index+2]}_lsst']
        past_color = catalog[f'mag_{bands[index]}_lsst']
        
        plt.hexbin(past_color-color,color-next_color, None, mincnt=1, cmap='turbo', gridsize=[400,200], bins='log')
        plt.xlabel(f'{bands[index+1]}-{bands[index+2]}',fontsize=13)
        plt.ylabel(f'{bands[index]}-{bands[index+1]}',fontsize=13)
        cbar = plt.colorbar()
        plt.xlim(-1,3)
        plt.ylim(-1,3)
    plt.show()

# %%
def color_color_red(catalog,xlim=[-1,3],ylim=[-1,3]):
    bands = ['u', 'g', 'r', 'i', 'z','y']
    i=1
    plt.figure(figsize=(12,12))
    for index in range(len(bands)-2):
        plt.subplot(3,2,i)
        i+=1
        color = catalog[f'mag_{bands[index+1]}_lsst']
        next_color = catalog[f'mag_{bands[index+2]}_lsst']
        past_color = catalog[f'mag_{bands[index]}_lsst']
        
        plt.hexbin(past_color-color,color-next_color, C=catalog['redshift'], mincnt=1, cmap='turbo', gridsize=[400,200])
        plt.xlabel(f'{bands[index+1]}-{bands[index+2]}',fontsize=13)
        plt.ylabel(f'{bands[index]}-{bands[index+1]}',fontsize=13)
        cbar = plt.colorbar(label='redshift')
        plt.xlim(xlim[0],xlim[1])
        plt.ylim(ylim[0],ylim[1])
    plt.show()

# %% [markdown]
# ## Reading data
#
# The data used here comes from the DESC PZ Working Group. We don't now if the reddening was removed.

# %%
data = pd.read_csv('sample_cosmodc2_w10year_errors.dat', sep =' ')

data.drop('dec',axis=1,inplace=True)

# %%
columns_map = {
    "#id": "redshift",
    "ra": "dec", 
    "sz": "ra",
    "u": "mag_u_lsst",
    "uerr": "mag_err_u_lsst",
    "g": "mag_g_lsst",
    "gerr": "mag_err_g_lsst",
    "r": "mag_r_lsst",
    "rerr": "mag_err_r_lsst",
    "i": "mag_i_lsst",
    "ierr": "mag_err_i_lsst",
    "y": "mag_y_lsst",
    "yerr": "mag_err_y_lsst",
    "z": "mag_z_lsst",
    "zerr": "mag_err_z_lsst",
    "galid": "galid"
}
data = data.rename(columns=columns_map)

# %%
data
# Out:
#           redshift         ra        dec  mag_u_lsst  mag_err_u_lsst  \
# 0           0.0220  62.584977 -40.334110     17.6159          0.0050
# 100         0.0489  62.737951 -40.310046     19.3351          0.0051
# 200         0.0258  61.679292 -41.217925     23.0562          0.0144
# 300         0.0292  62.836708 -40.058639     23.7464          0.0251
# 400         0.0336  62.349167 -40.069310     23.1186          0.0151
# ...            ...        ...        ...         ...             ...
# 10409900    2.8531  65.820556 -37.911725     27.6754          0.8820
# 10410000    2.8760  67.040719 -38.408924     28.2485          1.4946
# 10410100    2.9215  66.338044 -38.558236     26.7672          0.3827
# 10410200    3.0305  66.287684 -38.883792     29.0782          3.2079
# 10410300    2.9476  65.884390 -39.271043     25.8659          0.1675
#
#           mag_g_lsst  mag_err_g_lsst  mag_r_lsst  mag_err_r_lsst  mag_i_lsst  \
# 0            16.3943          0.0050     15.9683          0.0050     15.7529
# 100          18.0216          0.0050     17.4491          0.0050     17.1498
# 200          21.9222          0.0053     21.5337          0.0051     21.3164
# 300          22.4624          0.0057     21.8373          0.0051     21.5111
# 400          22.0724          0.0054     21.7829          0.0051     21.6102
# ...              ...             ...         ...             ...         ...
# 10409900     25.8391          0.0488     25.4753          0.0307     25.2173
# 10410000     25.4134          0.0334     25.0840          0.0217     25.1027
# 10410100     25.0215          0.0237     24.7763          0.0167     24.8933
# 10410200     25.3102          0.0305     25.1340          0.0227     25.2163
# 10410300     24.7771          0.0193     24.5671          0.0141     24.5893
#
#           mag_err_i_lsst  mag_z_lsst  mag_err_z_lsst  mag_y_lsst  \
# 0                 0.0050     15.6386          0.0050     15.5775
# 100               0.0050     16.9570          0.0050     16.8299
# 200               0.0052     21.2373          0.0055     21.1947
# 300               0.0053     21.3566          0.0056     21.2626
# 400               0.0053     21.5308          0.0059     21.5019
# ...                  ...         ...             ...         ...
# 10409900          0.0455     25.1953          0.0900     25.0288
# 10410000          0.0410     25.0662          0.0800     25.3066
# 10410100          0.0340     24.8028          0.0628     24.8250
# 10410200          0.0454     25.4343          0.1121     25.5566
# 10410300          0.0259     24.7606          0.0604     24.6250
#
#           mag_err_y_lsst       galid      Av
# 0                 0.0050 -2147483648  0.0655
# 100               0.0050 -2147483648  0.0980
# 200               0.0085 -2147483648  0.1502
# 300               0.0089 -2147483648  0.2221
# 400               0.0105 -2147483648  0.1636
# ...                  ...         ...     ...
# 10409900          0.2364 -2147483648  0.0000
# 10410000          0.3053 -2147483648  0.2084
# 10410100          0.1960 -2147483648  0.1290
# 10410200          0.3843 -2147483648  0.0070
# 10410300          0.1630 -2147483648  1.2032
#
# [104104 rows x 17 columns]

# %% [markdown]
# ## Removing mag 99
#
# Only the u band have magnitude 99

# %%
data = data[data['mag_u_lsst']<99]

# %%
data = data[data['mag_i_lsst']>16]

# %%
data = data[data['mag_i_lsst']<25]

# %%
data
# Out:
#           redshift         ra        dec  mag_u_lsst  mag_err_u_lsst  \
# 100         0.0489  62.737951 -40.310046     19.3351          0.0051
# 200         0.0258  61.679292 -41.217925     23.0562          0.0144
# 300         0.0292  62.836708 -40.058639     23.7464          0.0251
# 400         0.0336  62.349167 -40.069310     23.1186          0.0151
# 500         0.0325  61.570107 -40.943441     23.6385          0.0229
# ...            ...        ...        ...         ...             ...
# 10409400    2.7844  66.351051 -38.018459     25.3790          0.1074
# 10409500    2.7824  66.405631 -37.914837     25.5534          0.1259
# 10409700    2.8185  66.908028 -38.385662     25.9781          0.1856
# 10410100    2.9215  66.338044 -38.558236     26.7672          0.3827
# 10410300    2.9476  65.884390 -39.271043     25.8659          0.1675
#
#           mag_g_lsst  mag_err_g_lsst  mag_r_lsst  mag_err_r_lsst  mag_i_lsst  \
# 100          18.0216          0.0050     17.4491          0.0050     17.1498
# 200          21.9222          0.0053     21.5337          0.0051     21.3164
# 300          22.4624          0.0057     21.8373          0.0051     21.5111
# 400          22.0724          0.0054     21.7829          0.0051     21.6102
# 500          22.5864          0.0058     22.2722          0.0053     22.1141
# ...              ...             ...         ...             ...         ...
# 10409400     24.5816          0.0164     24.4598          0.0130     24.5213
# 10409500     24.7041          0.0181     24.6128          0.0147     24.6322
# 10409700     24.8880          0.0211     24.6841          0.0155     24.5622
# 10410100     25.0215          0.0237     24.7763          0.0167     24.8933
# 10410300     24.7771          0.0193     24.5671          0.0141     24.5893
#
#           mag_err_i_lsst  mag_z_lsst  mag_err_z_lsst  mag_y_lsst  \
# 100               0.0050     16.9570          0.0050     16.8299
# 200               0.0052     21.2373          0.0055     21.1947
# 300               0.0053     21.3566          0.0056     21.2626
# 400               0.0053     21.5308          0.0059     21.5019
# 500               0.0057     22.0690          0.0071     22.0160
# ...                  ...         ...             ...         ...
# 10409400          0.0244     24.6167          0.0530     24.4288
# 10409500          0.0269     24.7233          0.0584     24.4336
# 10409700          0.0253     24.5302          0.0490     24.4957
# 10410100          0.0340     24.8028          0.0628     24.8250
# 10410300          0.0259     24.7606          0.0604     24.6250
#
#           mag_err_y_lsst       galid      Av
# 100               0.0050 -2147483648  0.0980
# 200               0.0085 -2147483648  0.1502
# 300               0.0089 -2147483648  0.2221
# 400               0.0105 -2147483648  0.1636
# 500               0.0156 -2147483648 -0.0000
# ...                  ...         ...     ...
# 10409400          0.1361 -2147483648  0.6017
# 10409500          0.1367 -2147483648  0.6180
# 10409700          0.1447 -2147483648 -0.0000
# 10410100          0.1960 -2147483648  0.1290
# 10410300          0.1630 -2147483648  1.2032
#
# [81068 rows x 17 columns]

# %% [markdown]
# ## Plotting the data and analysing

# %%
plot_errors(data)

# %%
mag_histogram(data)

# %%
bands=['u','g','r','i','z','y']
i=1
plt.figure(figsize=(8,8))
for band in bands:
    print(max(data[f'mag_err_{band}_lsst']))
    plt.subplot(3,2,i)
    plt.scatter(data[f'mag_{band}_lsst'],data[f'mag_err_{band}_lsst'],s=0.1,color='red',label=band)
    plt.legend()
    plt.ylim(0,5)
    plt.xlim(0,33)
    i+=1
# Out:
# 17.9587
# 0.5455
# 0.0818
# 0.0374
# 0.0968
# 0.7008

# %%
plt.scatter(data['mag_g_lsst']-data['mag_r_lsst'],data['mag_i_lsst']-data['mag_z_lsst'],s=0.1,color='red')

# %%
mag_color(data)

# %%
color_color(data)

# %%
color_color_red(data,[-0.5,2],[-0.5,1.5])

# %%
cor_cor(data)

# %%
t = plt.scatter(data['ra'],data['dec'], c=data['Av'],cmap='turbo',s=1,vmax=0.51)
plt.colorbar(t, orientation='vertical', shrink=0.8, aspect=10, pad=0.02)
#plt.xlim(62,68)
#plt.ylim(-44,-40)

# %%
plt.scatter(data['ra'],data['dec'], c=data['redshift'],cmap='turbo',s=1)
plt.colorbar()
#plt.xlim(64,68)
#plt.ylim(-40,-34)

# %% [markdown]
# ## Choosing training fraction
#
# In this section you should choose a fraction of the data that will be used in training and validation.

# %%
fraction = 0.5 # choose a value between 0 and 1

training_csv = data.sample(round(len(data)*fraction),random_state=40)
validation_csv = data.drop(training_csv.index)

# %%
training_csv = training_csv.sort_index()
training_csv
# Out:
#           redshift         ra        dec  mag_u_lsst  mag_err_u_lsst  \
# 200         0.0258  61.679292 -41.217925     23.0562          0.0144
# 400         0.0336  62.349167 -40.069310     23.1186          0.0151
# 500         0.0325  61.570107 -40.943441     23.6385          0.0229
# 600         0.0706  61.901785 -39.756100     19.2633          0.0051
# 800         0.0672  61.260704 -40.817689     25.3300          0.1027
# ...            ...        ...        ...         ...             ...
# 10409000    2.6662  67.014047 -38.446636     24.7803          0.0624
# 10409100    2.6959  65.196200 -39.096484     23.3849          0.0186
# 10409400    2.7844  66.351051 -38.018459     25.3790          0.1074
# 10409700    2.8185  66.908028 -38.385662     25.9781          0.1856
# 10410300    2.9476  65.884390 -39.271043     25.8659          0.1675
#
#           mag_g_lsst  mag_err_g_lsst  mag_r_lsst  mag_err_r_lsst  mag_i_lsst  \
# 200          21.9222          0.0053     21.5337          0.0051     21.3164
# 400          22.0724          0.0054     21.7829          0.0051     21.6102
# 500          22.5864          0.0058     22.2722          0.0053     22.1141
# 600          18.0039          0.0050     17.3490          0.0050     16.9852
# 800          23.9432          0.0102     23.2641          0.0065     22.9297
# ...              ...             ...         ...             ...         ...
# 10409000     24.3077          0.0132     24.2860          0.0114     24.3037
# 10409100     22.8887          0.0062     22.8386          0.0057     22.8193
# 10409400     24.5816          0.0164     24.4598          0.0130     24.5213
# 10409700     24.8880          0.0211     24.6841          0.0155     24.5622
# 10410300     24.7771          0.0193     24.5671          0.0141     24.5893
#
#           mag_err_i_lsst  mag_z_lsst  mag_err_z_lsst  mag_y_lsst  \
# 200               0.0052     21.2373          0.0055     21.1947
# 400               0.0053     21.5308          0.0059     21.5019
# 500               0.0057     22.0690          0.0071     22.0160
# 600               0.0050     16.6671          0.0050     16.4754
# 800               0.0076     22.7424          0.0106     22.7086
# ...                  ...         ...             ...         ...
# 10409000          0.0202     24.4122          0.0440     24.5848
# 10409100          0.0072     22.8893          0.0119     22.9282
# 10409400          0.0244     24.6167          0.0530     24.4288
# 10409700          0.0253     24.5302          0.0490     24.4957
# 10410300          0.0259     24.7606          0.0604     24.6250
#
#           mag_err_y_lsst       galid      Av
# 200               0.0085 -2147483648  0.1502
# 400               0.0105 -2147483648  0.1636
# 500               0.0156 -2147483648 -0.0000
# 600               0.0050 -2147483648  1.7394
# 800               0.0283 -2147483648  0.1545
# ...                  ...         ...     ...
# 10409000          0.1571 -2147483648  0.0654
# 10409100          0.0345 -2147483648 -0.0000
# 10409400          0.1361 -2147483648  0.6017
# 10409700          0.1447 -2147483648 -0.0000
# 10410300          0.1630 -2147483648  1.2032
#
# [40534 rows x 17 columns]

# %%
validation_csv
# Out:
#           redshift         ra        dec  mag_u_lsst  mag_err_u_lsst  \
# 100         0.0489  62.737951 -40.310046     19.3351          0.0051
# 300         0.0292  62.836708 -40.058639     23.7464          0.0251
# 700         0.0634  61.389067 -39.275928     24.7660          0.0616
# 900         0.0522  62.217480 -40.393876     22.1550          0.0081
# 1200        0.0613  61.891983 -40.901151     24.8306          0.0653
# ...            ...        ...        ...         ...             ...
# 10408100    2.6014  65.463870 -37.948711     24.8793          0.0683
# 10408500    2.6136  65.766604 -39.440811     25.6927          0.1430
# 10408900    2.7088  66.906982 -38.715204     24.7397          0.0602
# 10409500    2.7824  66.405631 -37.914837     25.5534          0.1259
# 10410100    2.9215  66.338044 -38.558236     26.7672          0.3827
#
#           mag_g_lsst  mag_err_g_lsst  mag_r_lsst  mag_err_r_lsst  mag_i_lsst  \
# 100          18.0216          0.0050     17.4491          0.0050     17.1498
# 300          22.4624          0.0057     21.8373          0.0051     21.5111
# 700          23.3739          0.0074     22.7517          0.0056     22.4174
# 900          20.8445          0.0051     20.3781          0.0050     20.1520
# 1200         23.6870          0.0087     23.3077          0.0066     23.0937
# ...              ...             ...         ...             ...         ...
# 10408100     24.5598          0.0161     24.5500          0.0139     24.6695
# 10408500     24.8681          0.0208     24.5418          0.0138     24.3986
# 10408900     24.0352          0.0109     23.9939          0.0093     24.0455
# 10409500     24.7041          0.0181     24.6128          0.0147     24.6322
# 10410100     25.0215          0.0237     24.7763          0.0167     24.8933
#
#           mag_err_i_lsst  mag_z_lsst  mag_err_z_lsst  mag_y_lsst  \
# 100               0.0050     16.9570          0.0050     16.8299
# 300               0.0053     21.3566          0.0056     21.2626
# 700               0.0062     22.2729          0.0079     22.1954
# 900               0.0050     20.0553          0.0051     19.9874
# 1200              0.0082     23.0242          0.0132     23.0114
# ...                  ...         ...             ...         ...
# 10408100          0.0278     24.6807          0.0562     24.4872
# 10408500          0.0219     24.4462          0.0454     24.2010
# 10408900          0.0163     24.0657          0.0321     24.2416
# 10409500          0.0269     24.7233          0.0584     24.4336
# 10410100          0.0340     24.8028          0.0628     24.8250
#
#           mag_err_y_lsst       galid      Av
# 100               0.0050 -2147483648  0.0980
# 300               0.0089 -2147483648  0.2221
# 700               0.0181 -2147483648  0.0332
# 900               0.0055 -2147483648  0.0077
# 1200              0.0372 -2147483648 -0.0001
# ...                  ...         ...     ...
# 10408100          0.1436 -2147483648  0.0089
# 10408500          0.1104 -2147483648 -0.0000
# 10408900          0.1146 -2147483648  0.0022
# 10409500          0.1367 -2147483648  0.6180
# 10410100          0.1960 -2147483648  0.1290
#
# [40534 rows x 17 columns]

# %% [markdown]
# ## Getting the maximum and minimum redshift from training sample for FlexzBoost configurations

# %%
z_max = max(training_csv['redshift'])
z_min = min(training_csv['redshift'])

# %% [markdown]
# ## Changing the data to a PqHandle

# %%
training_sample = DS.add_data(data=training_csv, handle_class=PqHandle, key='redshift')

# %%
validation_sample = DS.add_data(data=validation_csv, handle_class=PqHandle, key='redshift')

# %%
training_sample.data
# Out:
#           redshift         ra        dec  mag_u_lsst  mag_err_u_lsst  \
# 200         0.0258  61.679292 -41.217925     23.0562          0.0144
# 400         0.0336  62.349167 -40.069310     23.1186          0.0151
# 500         0.0325  61.570107 -40.943441     23.6385          0.0229
# 600         0.0706  61.901785 -39.756100     19.2633          0.0051
# 800         0.0672  61.260704 -40.817689     25.3300          0.1027
# ...            ...        ...        ...         ...             ...
# 10409000    2.6662  67.014047 -38.446636     24.7803          0.0624
# 10409100    2.6959  65.196200 -39.096484     23.3849          0.0186
# 10409400    2.7844  66.351051 -38.018459     25.3790          0.1074
# 10409700    2.8185  66.908028 -38.385662     25.9781          0.1856
# 10410300    2.9476  65.884390 -39.271043     25.8659          0.1675
#
#           mag_g_lsst  mag_err_g_lsst  mag_r_lsst  mag_err_r_lsst  mag_i_lsst  \
# 200          21.9222          0.0053     21.5337          0.0051     21.3164
# 400          22.0724          0.0054     21.7829          0.0051     21.6102
# 500          22.5864          0.0058     22.2722          0.0053     22.1141
# 600          18.0039          0.0050     17.3490          0.0050     16.9852
# 800          23.9432          0.0102     23.2641          0.0065     22.9297
# ...              ...             ...         ...             ...         ...
# 10409000     24.3077          0.0132     24.2860          0.0114     24.3037
# 10409100     22.8887          0.0062     22.8386          0.0057     22.8193
# 10409400     24.5816          0.0164     24.4598          0.0130     24.5213
# 10409700     24.8880          0.0211     24.6841          0.0155     24.5622
# 10410300     24.7771          0.0193     24.5671          0.0141     24.5893
#
#           mag_err_i_lsst  mag_z_lsst  mag_err_z_lsst  mag_y_lsst  \
# 200               0.0052     21.2373          0.0055     21.1947
# 400               0.0053     21.5308          0.0059     21.5019
# 500               0.0057     22.0690          0.0071     22.0160
# 600               0.0050     16.6671          0.0050     16.4754
# 800               0.0076     22.7424          0.0106     22.7086
# ...                  ...         ...             ...         ...
# 10409000          0.0202     24.4122          0.0440     24.5848
# 10409100          0.0072     22.8893          0.0119     22.9282
# 10409400          0.0244     24.6167          0.0530     24.4288
# 10409700          0.0253     24.5302          0.0490     24.4957
# 10410300          0.0259     24.7606          0.0604     24.6250
#
#           mag_err_y_lsst       galid      Av
# 200               0.0085 -2147483648  0.1502
# 400               0.0105 -2147483648  0.1636
# 500               0.0156 -2147483648 -0.0000
# 600               0.0050 -2147483648  1.7394
# 800               0.0283 -2147483648  0.1545
# ...                  ...         ...     ...
# 10409000          0.1571 -2147483648  0.0654
# 10409100          0.0345 -2147483648 -0.0000
# 10409400          0.1361 -2147483648  0.6017
# 10409700          0.1447 -2147483648 -0.0000
# 10410300          0.1630 -2147483648  1.2032
#
# [40534 rows x 17 columns]

# %%
validation_sample.data
# Out:
#           redshift         ra        dec  mag_u_lsst  mag_err_u_lsst  \
# 100         0.0489  62.737951 -40.310046     19.3351          0.0051
# 300         0.0292  62.836708 -40.058639     23.7464          0.0251
# 700         0.0634  61.389067 -39.275928     24.7660          0.0616
# 900         0.0522  62.217480 -40.393876     22.1550          0.0081
# 1200        0.0613  61.891983 -40.901151     24.8306          0.0653
# ...            ...        ...        ...         ...             ...
# 10408100    2.6014  65.463870 -37.948711     24.8793          0.0683
# 10408500    2.6136  65.766604 -39.440811     25.6927          0.1430
# 10408900    2.7088  66.906982 -38.715204     24.7397          0.0602
# 10409500    2.7824  66.405631 -37.914837     25.5534          0.1259
# 10410100    2.9215  66.338044 -38.558236     26.7672          0.3827
#
#           mag_g_lsst  mag_err_g_lsst  mag_r_lsst  mag_err_r_lsst  mag_i_lsst  \
# 100          18.0216          0.0050     17.4491          0.0050     17.1498
# 300          22.4624          0.0057     21.8373          0.0051     21.5111
# 700          23.3739          0.0074     22.7517          0.0056     22.4174
# 900          20.8445          0.0051     20.3781          0.0050     20.1520
# 1200         23.6870          0.0087     23.3077          0.0066     23.0937
# ...              ...             ...         ...             ...         ...
# 10408100     24.5598          0.0161     24.5500          0.0139     24.6695
# 10408500     24.8681          0.0208     24.5418          0.0138     24.3986
# 10408900     24.0352          0.0109     23.9939          0.0093     24.0455
# 10409500     24.7041          0.0181     24.6128          0.0147     24.6322
# 10410100     25.0215          0.0237     24.7763          0.0167     24.8933
#
#           mag_err_i_lsst  mag_z_lsst  mag_err_z_lsst  mag_y_lsst  \
# 100               0.0050     16.9570          0.0050     16.8299
# 300               0.0053     21.3566          0.0056     21.2626
# 700               0.0062     22.2729          0.0079     22.1954
# 900               0.0050     20.0553          0.0051     19.9874
# 1200              0.0082     23.0242          0.0132     23.0114
# ...                  ...         ...             ...         ...
# 10408100          0.0278     24.6807          0.0562     24.4872
# 10408500          0.0219     24.4462          0.0454     24.2010
# 10408900          0.0163     24.0657          0.0321     24.2416
# 10409500          0.0269     24.7233          0.0584     24.4336
# 10410100          0.0340     24.8028          0.0628     24.8250
#
#           mag_err_y_lsst       galid      Av
# 100               0.0050 -2147483648  0.0980
# 300               0.0089 -2147483648  0.2221
# 700               0.0181 -2147483648  0.0332
# 900               0.0055 -2147483648  0.0077
# 1200              0.0372 -2147483648 -0.0001
# ...                  ...         ...     ...
# 10408100          0.1436 -2147483648  0.0089
# 10408500          0.1104 -2147483648 -0.0000
# 10408900          0.1146 -2147483648  0.0022
# 10409500          0.1367 -2147483648  0.6180
# 10410100          0.1960 -2147483648  0.1290
#
# [40534 rows x 17 columns]

# %%
# saving data used
validation_sample.data.to_hdf(f'/home/iago/ic_cosmo/samples/validation_DP02_i_{round(max(data['mag_i_lsst']),1)}.hdf5',key='data')

# %% [markdown]
# # Configuring algorithm, training and validating

# %% [markdown]
# ## Setting FlexzBoost
#
# Here we can change the configurations of the algorithm.
#
# List of possible regressions:
# reg:squarederror // reg:linear // reg:pseudohubererror // reg:absoluteerror

# %%
limits = [] # selecting the magnitude limits of each band for FlexzBoost settings
for band in ['mag_u_lsst','mag_g_lsst','mag_r_lsst','mag_i_lsst','mag_z_lsst','mag_y_lsst']:
    limits.append(max(data[band]))
limits
# Out:
# [30.9486, 28.4773, 26.5573, 24.9999, 25.2748, 26.2089]

# %%
############################ FlexzBoost configurations #########################################

basis_system = 'Fourier'
reg = 'squarederror'
max_basis = 35
depth = 8 

################################################################################################

fz_dict = dict(zmin=z_min, zmax=z_max, nzbins=201,
               trainfrac=fraction, bumpmin=0.02, bumpmax=0.35,
               nbump=20, sharpmin=0.7, sharpmax=2.1, nsharp=15,
               max_basis=max_basis, basis_system= basis_system,
               bands = ['mag_u_lsst','mag_g_lsst','mag_r_lsst','mag_i_lsst','mag_z_lsst','mag_y_lsst'],
               err_bands = ['mag_err_u_lsst','mag_err_g_lsst','mag_err_z_lsst','mag_err_i_lsst','mag_err_z_lsst','mag_err_y_lsst'],
               mag_limits={'mag_u_lsst':limits[0],'mag_g_lsst':limits[1],'mag_r_lsst':limits[2],'mag_i_lsst':limits[3],'mag_z_lsst':limits[4],'mag_y_lsst':limits[5],},
               hdf5_groupname='',
               regression_params={'max_depth': depth,'objective':f'reg:{reg}'})

fz_modelfile = 'demo_FZB_model.pkl'

# %% [markdown]
# ## Training and Validation (LONG TIME TO RUN!!!)

# %%
inform_pzflex = FlexZBoostInformer.make_stage(name='inform_fzboost', model=fz_modelfile, **fz_dict)

# %%
# %%time
inform_pzflex.inform(training_sample) #training algorithm
# Out:
# stacking some data...
# read in training data
# fit the model...
# finding best bump thresh...
# finding best sharpen parameter...
# Retraining with full training set...
# Inserting handle into data store.  model_inform_fzboost: inprogress_demo_FZB_model.pkl, inform_fzboost
# CPU times: user 4min 21s, sys: 29 s, total: 4min 50s
# Wall time: 4min 42s

# %%
table_conv = TableConverter.make_stage(name='table_conv_test', output_format='numpyDict');
test_sample_table = table_conv(validation_sample)
# Out:
# Inserting handle into data store.  output_table_conv_test: inprogress_output_table_conv_test.hdf5, table_conv_test

# %%
estimate_fzb = FlexZBoostEstimator.make_stage(
    name='estimate_fzb', 
    hdf5_groupname='',
    bands = ['mag_u_lsst','mag_g_lsst','mag_r_lsst','mag_i_lsst','mag_z_lsst','mag_y_lsst'],
    err_bands = ['mag_err_u_lsst','mag_err_g_lsst','mag_err_z_lsst','mag_err_i_lsst','mag_err_z_lsst','mag_err_y_lsst'],
    mag_limits={'mag_u_lsst':limits[0],'mag_g_lsst':limits[1],'mag_r_lsst':limits[2],'mag_i_lsst':limits[3],'mag_z_lsst':limits[4],'mag_y_lsst':limits[5],},
    model=inform_pzflex.get_handle('model'),
    filters="path",
    zmax = z_max,
    chunk_size=20
)

# %%
output_fzb = estimate_fzb.estimate(test_sample_table) #testing
# Out:
# Process 0 running estimator on chunk 0 - 20
# Process 0 estimating PZ PDF for rows 0 - 20
# Inserting handle into data store.  output_estimate_fzb: inprogress_output_estimate_fzb.hdf5, estimate_fzb
# Process 0 running estimator on chunk 20 - 40
# Process 0 estimating PZ PDF for rows 20 - 40
# Process 0 running estimator on chunk 40 - 60
# Process 0 estimating PZ PDF for rows 40 - 60
# Process 0 running estimator on chunk 60 - 80
# Process 0 estimating PZ PDF for rows 60 - 80
# Process 0 running estimator on chunk 80 - 100
# Process 0 estimating PZ PDF for rows 80 - 100
# Process 0 running estimator on chunk 100 - 120
# Process 0 estimating PZ PDF for rows 100 - 120
# Process 0 running estimator on chunk 120 - 140
# Process 0 estimating PZ PDF for rows 120 - 140
# Process 0 running estimator on chunk 140 - 160
# Process 0 estimating PZ PDF for rows 140 - 160
# Process 0 running estimator on chunk 160 - 180
# Process 0 estimating PZ PDF for rows 160 - 180
# Process 0 running estimator on chunk 180 - 200
# Process 0 estimating PZ PDF for rows 180 - 200
# Process 0 running estimator on chunk 200 - 220
# Process 0 estimating PZ PDF for rows 200 - 220
# Process 0 running estimator on chunk 220 - 240
# Process 0 estimating PZ PDF for rows 220 - 240
# Process 0 running estimator on chunk 240 - 260
# Process 0 estimating PZ PDF for rows 240 - 260
# Process 0 running estimator on chunk 260 - 280
# Process 0 estimating PZ PDF for rows 260 - 280
# Process 0 running estimator on chunk 280 - 300
# Process 0 estimating PZ PDF for rows 280 - 300
# Process 0 running estimator on chunk 300 - 320
# Process 0 estimating PZ PDF for rows 300 - 320
# Process 0 running estimator on chunk 320 - 340
# Process 0 estimating PZ PDF for rows 320 - 340
# Process 0 running estimator on chunk 340 - 360
# Process 0 estimating PZ PDF for rows 340 - 360
# Process 0 running estimator on chunk 360 - 380
# Process 0 estimating PZ PDF for rows 360 - 380
# Process 0 running estimator on chunk 380 - 400
# Process 0 estimating PZ PDF for rows 380 - 400
# Process 0 running estimator on chunk 400 - 420
# Process 0 estimating PZ PDF for rows 400 - 420
# Process 0 running estimator on chunk 420 - 440
# Process 0 estimating PZ PDF for rows 420 - 440
# Process 0 running estimator on chunk 440 - 460
# Process 0 estimating PZ PDF for rows 440 - 460
# Process 0 running estimator on chunk 460 - 480
# Process 0 estimating PZ PDF for rows 460 - 480
# Process 0 running estimator on chunk 480 - 500
# Process 0 estimating PZ PDF for rows 480 - 500
# Process 0 running estimator on chunk 500 - 520
# Process 0 estimating PZ PDF for rows 500 - 520
# Process 0 running estimator on chunk 520 - 540
# Process 0 estimating PZ PDF for rows 520 - 540
# Process 0 running estimator on chunk 540 - 560
# Process 0 estimating PZ PDF for rows 540 - 560
# Process 0 running estimator on chunk 560 - 580
# Process 0 estimating PZ PDF for rows 560 - 580
# Process 0 running estimator on chunk 580 - 600
# Process 0 estimating PZ PDF for rows 580 - 600
# Process 0 running estimator on chunk 600 - 620
# Process 0 estimating PZ PDF for rows 600 - 620
# Process 0 running estimator on chunk 620 - 640
# Process 0 estimating PZ PDF for rows 620 - 640
# Process 0 running estimator on chunk 640 - 660
# Process 0 estimating PZ PDF for rows 640 - 660
# Process 0 running estimator on chunk 660 - 680
# Process 0 estimating PZ PDF for rows 660 - 680
# Process 0 running estimator on chunk 680 - 700
# Process 0 estimating PZ PDF for rows 680 - 700
# Process 0 running estimator on chunk 700 - 720
# Process 0 estimating PZ PDF for rows 700 - 720
# Process 0 running estimator on chunk 720 - 740
# Process 0 estimating PZ PDF for rows 720 - 740
# Process 0 running estimator on chunk 740 - 760
# Process 0 estimating PZ PDF for rows 740 - 760
# Process 0 running estimator on chunk 760 - 780
# Process 0 estimating PZ PDF for rows 760 - 780
# Process 0 running estimator on chunk 780 - 800
# Process 0 estimating PZ PDF for rows 780 - 800
# Process 0 running estimator on chunk 800 - 820
# Process 0 estimating PZ PDF for rows 800 - 820
# Process 0 running estimator on chunk 820 - 840
# Process 0 estimating PZ PDF for rows 820 - 840
# Process 0 running estimator on chunk 840 - 860
# Process 0 estimating PZ PDF for rows 840 - 860
# Process 0 running estimator on chunk 860 - 880
# Process 0 estimating PZ PDF for rows 860 - 880
# Process 0 running estimator on chunk 880 - 900
# Process 0 estimating PZ PDF for rows 880 - 900
# Process 0 running estimator on chunk 900 - 920
# Process 0 estimating PZ PDF for rows 900 - 920
# Process 0 running estimator on chunk 920 - 940
# Process 0 estimating PZ PDF for rows 920 - 940
# Process 0 running estimator on chunk 940 - 960
# Process 0 estimating PZ PDF for rows 940 - 960
# Process 0 running estimator on chunk 960 - 980
# Process 0 estimating PZ PDF for rows 960 - 980
# Process 0 running estimator on chunk 980 - 1000
# Process 0 estimating PZ PDF for rows 980 - 1,000
# Process 0 running estimator on chunk 1000 - 1020
# Process 0 estimating PZ PDF for rows 1,000 - 1,020
# Process 0 running estimator on chunk 1020 - 1040
# Process 0 estimating PZ PDF for rows 1,020 - 1,040
# Process 0 running estimator on chunk 1040 - 1060
# Process 0 estimating PZ PDF for rows 1,040 - 1,060
# Process 0 running estimator on chunk 1060 - 1080
# Process 0 estimating PZ PDF for rows 1,060 - 1,080
# Process 0 running estimator on chunk 1080 - 1100
# Process 0 estimating PZ PDF for rows 1,080 - 1,100
# Process 0 running estimator on chunk 1100 - 1120
# Process 0 estimating PZ PDF for rows 1,100 - 1,120
# Process 0 running estimator on chunk 1120 - 1140
# Process 0 estimating PZ PDF for rows 1,120 - 1,140
# Process 0 running estimator on chunk 1140 - 1160
# Process 0 estimating PZ PDF for rows 1,140 - 1,160
# Process 0 running estimator on chunk 1160 - 1180
# Process 0 estimating PZ PDF for rows 1,160 - 1,180
# Process 0 running estimator on chunk 1180 - 1200
# Process 0 estimating PZ PDF for rows 1,180 - 1,200
# Process 0 running estimator on chunk 1200 - 1220
# Process 0 estimating PZ PDF for rows 1,200 - 1,220
# Process 0 running estimator on chunk 1220 - 1240
# Process 0 estimating PZ PDF for rows 1,220 - 1,240
# Process 0 running estimator on chunk 1240 - 1260
# Process 0 estimating PZ PDF for rows 1,240 - 1,260
# Process 0 running estimator on chunk 1260 - 1280
# Process 0 estimating PZ PDF for rows 1,260 - 1,280
# Process 0 running estimator on chunk 1280 - 1300
# Process 0 estimating PZ PDF for rows 1,280 - 1,300
# Process 0 running estimator on chunk 1300 - 1320
# Process 0 estimating PZ PDF for rows 1,300 - 1,320
# Process 0 running estimator on chunk 1320 - 1340
# Process 0 estimating PZ PDF for rows 1,320 - 1,340
# Process 0 running estimator on chunk 1340 - 1360
# Process 0 estimating PZ PDF for rows 1,340 - 1,360
# Process 0 running estimator on chunk 1360 - 1380
# Process 0 estimating PZ PDF for rows 1,360 - 1,380
# Process 0 running estimator on chunk 1380 - 1400
# Process 0 estimating PZ PDF for rows 1,380 - 1,400
# Process 0 running estimator on chunk 1400 - 1420
# Process 0 estimating PZ PDF for rows 1,400 - 1,420
# Process 0 running estimator on chunk 1420 - 1440
# Process 0 estimating PZ PDF for rows 1,420 - 1,440
# Process 0 running estimator on chunk 1440 - 1460
# Process 0 estimating PZ PDF for rows 1,440 - 1,460
# Process 0 running estimator on chunk 1460 - 1480
# Process 0 estimating PZ PDF for rows 1,460 - 1,480
# Process 0 running estimator on chunk 1480 - 1500
# Process 0 estimating PZ PDF for rows 1,480 - 1,500
# Process 0 running estimator on chunk 1500 - 1520
# Process 0 estimating PZ PDF for rows 1,500 - 1,520
# Process 0 running estimator on chunk 1520 - 1540
# Process 0 estimating PZ PDF for rows 1,520 - 1,540
# Process 0 running estimator on chunk 1540 - 1560
# Process 0 estimating PZ PDF for rows 1,540 - 1,560
# Process 0 running estimator on chunk 1560 - 1580
# Process 0 estimating PZ PDF for rows 1,560 - 1,580
# Process 0 running estimator on chunk 1580 - 1600
# Process 0 estimating PZ PDF for rows 1,580 - 1,600
# Process 0 running estimator on chunk 1600 - 1620
# Process 0 estimating PZ PDF for rows 1,600 - 1,620
# Process 0 running estimator on chunk 1620 - 1640
# Process 0 estimating PZ PDF for rows 1,620 - 1,640
# Process 0 running estimator on chunk 1640 - 1660
# Process 0 estimating PZ PDF for rows 1,640 - 1,660
# Process 0 running estimator on chunk 1660 - 1680
# Process 0 estimating PZ PDF for rows 1,660 - 1,680
# Process 0 running estimator on chunk 1680 - 1700
# Process 0 estimating PZ PDF for rows 1,680 - 1,700
# Process 0 running estimator on chunk 1700 - 1720
# Process 0 estimating PZ PDF for rows 1,700 - 1,720
# Process 0 running estimator on chunk 1720 - 1740
# Process 0 estimating PZ PDF for rows 1,720 - 1,740
# Process 0 running estimator on chunk 1740 - 1760
# Process 0 estimating PZ PDF for rows 1,740 - 1,760
# Process 0 running estimator on chunk 1760 - 1780
# Process 0 estimating PZ PDF for rows 1,760 - 1,780
# Process 0 running estimator on chunk 1780 - 1800
# Process 0 estimating PZ PDF for rows 1,780 - 1,800
# Process 0 running estimator on chunk 1800 - 1820
# Process 0 estimating PZ PDF for rows 1,800 - 1,820
# Process 0 running estimator on chunk 1820 - 1840
# Process 0 estimating PZ PDF for rows 1,820 - 1,840
# Process 0 running estimator on chunk 1840 - 1860
# Process 0 estimating PZ PDF for rows 1,840 - 1,860
# Process 0 running estimator on chunk 1860 - 1880
# Process 0 estimating PZ PDF for rows 1,860 - 1,880
# Process 0 running estimator on chunk 1880 - 1900
# Process 0 estimating PZ PDF for rows 1,880 - 1,900
# Process 0 running estimator on chunk 1900 - 1920
# Process 0 estimating PZ PDF for rows 1,900 - 1,920
# Process 0 running estimator on chunk 1920 - 1940
# Process 0 estimating PZ PDF for rows 1,920 - 1,940
# Process 0 running estimator on chunk 1940 - 1960
# Process 0 estimating PZ PDF for rows 1,940 - 1,960
# Process 0 running estimator on chunk 1960 - 1980
# Process 0 estimating PZ PDF for rows 1,960 - 1,980
# Process 0 running estimator on chunk 1980 - 2000
# Process 0 estimating PZ PDF for rows 1,980 - 2,000
# Process 0 running estimator on chunk 2000 - 2020
# Process 0 estimating PZ PDF for rows 2,000 - 2,020
# Process 0 running estimator on chunk 2020 - 2040
# Process 0 estimating PZ PDF for rows 2,020 - 2,040
# Process 0 running estimator on chunk 2040 - 2060
# Process 0 estimating PZ PDF for rows 2,040 - 2,060
# Process 0 running estimator on chunk 2060 - 2080
# Process 0 estimating PZ PDF for rows 2,060 - 2,080
# Process 0 running estimator on chunk 2080 - 2100
# Process 0 estimating PZ PDF for rows 2,080 - 2,100
# Process 0 running estimator on chunk 2100 - 2120
# Process 0 estimating PZ PDF for rows 2,100 - 2,120
# Process 0 running estimator on chunk 2120 - 2140
# Process 0 estimating PZ PDF for rows 2,120 - 2,140
# Process 0 running estimator on chunk 2140 - 2160
# Process 0 estimating PZ PDF for rows 2,140 - 2,160
# Process 0 running estimator on chunk 2160 - 2180
# Process 0 estimating PZ PDF for rows 2,160 - 2,180
# Process 0 running estimator on chunk 2180 - 2200
# Process 0 estimating PZ PDF for rows 2,180 - 2,200
# Process 0 running estimator on chunk 2200 - 2220
# Process 0 estimating PZ PDF for rows 2,200 - 2,220
# Process 0 running estimator on chunk 2220 - 2240
# Process 0 estimating PZ PDF for rows 2,220 - 2,240
# Process 0 running estimator on chunk 2240 - 2260
# Process 0 estimating PZ PDF for rows 2,240 - 2,260
# Process 0 running estimator on chunk 2260 - 2280
# Process 0 estimating PZ PDF for rows 2,260 - 2,280
# Process 0 running estimator on chunk 2280 - 2300
# Process 0 estimating PZ PDF for rows 2,280 - 2,300
# Process 0 running estimator on chunk 2300 - 2320
# Process 0 estimating PZ PDF for rows 2,300 - 2,320
# Process 0 running estimator on chunk 2320 - 2340
# Process 0 estimating PZ PDF for rows 2,320 - 2,340
# Process 0 running estimator on chunk 2340 - 2360
# Process 0 estimating PZ PDF for rows 2,340 - 2,360
# Process 0 running estimator on chunk 2360 - 2380
# Process 0 estimating PZ PDF for rows 2,360 - 2,380
# Process 0 running estimator on chunk 2380 - 2400
# Process 0 estimating PZ PDF for rows 2,380 - 2,400
# Process 0 running estimator on chunk 2400 - 2420
# Process 0 estimating PZ PDF for rows 2,400 - 2,420
# Process 0 running estimator on chunk 2420 - 2440
# Process 0 estimating PZ PDF for rows 2,420 - 2,440
# Process 0 running estimator on chunk 2440 - 2460
# Process 0 estimating PZ PDF for rows 2,440 - 2,460
# Process 0 running estimator on chunk 2460 - 2480
# Process 0 estimating PZ PDF for rows 2,460 - 2,480
# Process 0 running estimator on chunk 2480 - 2500
# Process 0 estimating PZ PDF for rows 2,480 - 2,500
# Process 0 running estimator on chunk 2500 - 2520
# Process 0 estimating PZ PDF for rows 2,500 - 2,520
# Process 0 running estimator on chunk 2520 - 2540
# Process 0 estimating PZ PDF for rows 2,520 - 2,540
# Process 0 running estimator on chunk 2540 - 2560
# Process 0 estimating PZ PDF for rows 2,540 - 2,560
# Process 0 running estimator on chunk 2560 - 2580
# Process 0 estimating PZ PDF for rows 2,560 - 2,580
# Process 0 running estimator on chunk 2580 - 2600
# Process 0 estimating PZ PDF for rows 2,580 - 2,600
# Process 0 running estimator on chunk 2600 - 2620
# Process 0 estimating PZ PDF for rows 2,600 - 2,620
# Process 0 running estimator on chunk 2620 - 2640
# Process 0 estimating PZ PDF for rows 2,620 - 2,640
# Process 0 running estimator on chunk 2640 - 2660
# Process 0 estimating PZ PDF for rows 2,640 - 2,660
# Process 0 running estimator on chunk 2660 - 2680
# Process 0 estimating PZ PDF for rows 2,660 - 2,680
# Process 0 running estimator on chunk 2680 - 2700
# Process 0 estimating PZ PDF for rows 2,680 - 2,700
# Process 0 running estimator on chunk 2700 - 2720
# Process 0 estimating PZ PDF for rows 2,700 - 2,720
# Process 0 running estimator on chunk 2720 - 2740
# Process 0 estimating PZ PDF for rows 2,720 - 2,740
# Process 0 running estimator on chunk 2740 - 2760
# Process 0 estimating PZ PDF for rows 2,740 - 2,760
# Process 0 running estimator on chunk 2760 - 2780
# Process 0 estimating PZ PDF for rows 2,760 - 2,780
# Process 0 running estimator on chunk 2780 - 2800
# Process 0 estimating PZ PDF for rows 2,780 - 2,800
# Process 0 running estimator on chunk 2800 - 2820
# Process 0 estimating PZ PDF for rows 2,800 - 2,820
# Process 0 running estimator on chunk 2820 - 2840
# Process 0 estimating PZ PDF for rows 2,820 - 2,840
# Process 0 running estimator on chunk 2840 - 2860
# Process 0 estimating PZ PDF for rows 2,840 - 2,860
# Process 0 running estimator on chunk 2860 - 2880
# Process 0 estimating PZ PDF for rows 2,860 - 2,880
# Process 0 running estimator on chunk 2880 - 2900
# Process 0 estimating PZ PDF for rows 2,880 - 2,900
# Process 0 running estimator on chunk 2900 - 2920
# Process 0 estimating PZ PDF for rows 2,900 - 2,920
# Process 0 running estimator on chunk 2920 - 2940
# Process 0 estimating PZ PDF for rows 2,920 - 2,940
# Process 0 running estimator on chunk 2940 - 2960
# Process 0 estimating PZ PDF for rows 2,940 - 2,960
# Process 0 running estimator on chunk 2960 - 2980
# Process 0 estimating PZ PDF for rows 2,960 - 2,980
# Process 0 running estimator on chunk 2980 - 3000
# Process 0 estimating PZ PDF for rows 2,980 - 3,000
# Process 0 running estimator on chunk 3000 - 3020
# Process 0 estimating PZ PDF for rows 3,000 - 3,020
# Process 0 running estimator on chunk 3020 - 3040
# Process 0 estimating PZ PDF for rows 3,020 - 3,040
# Process 0 running estimator on chunk 3040 - 3060
# Process 0 estimating PZ PDF for rows 3,040 - 3,060
# Process 0 running estimator on chunk 3060 - 3080
# Process 0 estimating PZ PDF for rows 3,060 - 3,080
# Process 0 running estimator on chunk 3080 - 3100
# Process 0 estimating PZ PDF for rows 3,080 - 3,100
# Process 0 running estimator on chunk 3100 - 3120
# Process 0 estimating PZ PDF for rows 3,100 - 3,120
# Process 0 running estimator on chunk 3120 - 3140
# Process 0 estimating PZ PDF for rows 3,120 - 3,140
# Process 0 running estimator on chunk 3140 - 3160
# Process 0 estimating PZ PDF for rows 3,140 - 3,160
# Process 0 running estimator on chunk 3160 - 3180
# Process 0 estimating PZ PDF for rows 3,160 - 3,180
# Process 0 running estimator on chunk 3180 - 3200
# Process 0 estimating PZ PDF for rows 3,180 - 3,200
# Process 0 running estimator on chunk 3200 - 3220
# Process 0 estimating PZ PDF for rows 3,200 - 3,220
# Process 0 running estimator on chunk 3220 - 3240
# Process 0 estimating PZ PDF for rows 3,220 - 3,240
# Process 0 running estimator on chunk 3240 - 3260
# Process 0 estimating PZ PDF for rows 3,240 - 3,260
# Process 0 running estimator on chunk 3260 - 3280
# Process 0 estimating PZ PDF for rows 3,260 - 3,280
# Process 0 running estimator on chunk 3280 - 3300
# Process 0 estimating PZ PDF for rows 3,280 - 3,300
# Process 0 running estimator on chunk 3300 - 3320
# Process 0 estimating PZ PDF for rows 3,300 - 3,320
# Process 0 running estimator on chunk 3320 - 3340
# Process 0 estimating PZ PDF for rows 3,320 - 3,340
# Process 0 running estimator on chunk 3340 - 3360
# Process 0 estimating PZ PDF for rows 3,340 - 3,360
# Process 0 running estimator on chunk 3360 - 3380
# Process 0 estimating PZ PDF for rows 3,360 - 3,380
# Process 0 running estimator on chunk 3380 - 3400
# Process 0 estimating PZ PDF for rows 3,380 - 3,400
# Process 0 running estimator on chunk 3400 - 3420
# Process 0 estimating PZ PDF for rows 3,400 - 3,420
# Process 0 running estimator on chunk 3420 - 3440
# Process 0 estimating PZ PDF for rows 3,420 - 3,440
# Process 0 running estimator on chunk 3440 - 3460
# Process 0 estimating PZ PDF for rows 3,440 - 3,460
# Process 0 running estimator on chunk 3460 - 3480
# Process 0 estimating PZ PDF for rows 3,460 - 3,480
# Process 0 running estimator on chunk 3480 - 3500
# Process 0 estimating PZ PDF for rows 3,480 - 3,500
# Process 0 running estimator on chunk 3500 - 3520
# Process 0 estimating PZ PDF for rows 3,500 - 3,520
# Process 0 running estimator on chunk 3520 - 3540
# Process 0 estimating PZ PDF for rows 3,520 - 3,540
# Process 0 running estimator on chunk 3540 - 3560
# Process 0 estimating PZ PDF for rows 3,540 - 3,560
# Process 0 running estimator on chunk 3560 - 3580
# Process 0 estimating PZ PDF for rows 3,560 - 3,580
# Process 0 running estimator on chunk 3580 - 3600
# Process 0 estimating PZ PDF for rows 3,580 - 3,600
# Process 0 running estimator on chunk 3600 - 3620
# Process 0 estimating PZ PDF for rows 3,600 - 3,620
# Process 0 running estimator on chunk 3620 - 3640
# Process 0 estimating PZ PDF for rows 3,620 - 3,640
# Process 0 running estimator on chunk 3640 - 3660
# Process 0 estimating PZ PDF for rows 3,640 - 3,660
# Process 0 running estimator on chunk 3660 - 3680
# Process 0 estimating PZ PDF for rows 3,660 - 3,680
# Process 0 running estimator on chunk 3680 - 3700
# Process 0 estimating PZ PDF for rows 3,680 - 3,700
# Process 0 running estimator on chunk 3700 - 3720
# Process 0 estimating PZ PDF for rows 3,700 - 3,720
# Process 0 running estimator on chunk 3720 - 3740
# Process 0 estimating PZ PDF for rows 3,720 - 3,740
# Process 0 running estimator on chunk 3740 - 3760
# Process 0 estimating PZ PDF for rows 3,740 - 3,760
# Process 0 running estimator on chunk 3760 - 3780
# Process 0 estimating PZ PDF for rows 3,760 - 3,780
# Process 0 running estimator on chunk 3780 - 3800
# Process 0 estimating PZ PDF for rows 3,780 - 3,800
# Process 0 running estimator on chunk 3800 - 3820
# Process 0 estimating PZ PDF for rows 3,800 - 3,820
# Process 0 running estimator on chunk 3820 - 3840
# Process 0 estimating PZ PDF for rows 3,820 - 3,840
# Process 0 running estimator on chunk 3840 - 3860
# Process 0 estimating PZ PDF for rows 3,840 - 3,860
# Process 0 running estimator on chunk 3860 - 3880
# Process 0 estimating PZ PDF for rows 3,860 - 3,880
# Process 0 running estimator on chunk 3880 - 3900
# Process 0 estimating PZ PDF for rows 3,880 - 3,900
# Process 0 running estimator on chunk 3900 - 3920
# Process 0 estimating PZ PDF for rows 3,900 - 3,920
# Process 0 running estimator on chunk 3920 - 3940
# Process 0 estimating PZ PDF for rows 3,920 - 3,940
# Process 0 running estimator on chunk 3940 - 3960
# Process 0 estimating PZ PDF for rows 3,940 - 3,960
# Process 0 running estimator on chunk 3960 - 3980
# Process 0 estimating PZ PDF for rows 3,960 - 3,980
# Process 0 running estimator on chunk 3980 - 4000
# Process 0 estimating PZ PDF for rows 3,980 - 4,000
# Process 0 running estimator on chunk 4000 - 4020
# Process 0 estimating PZ PDF for rows 4,000 - 4,020
# Process 0 running estimator on chunk 4020 - 4040
# Process 0 estimating PZ PDF for rows 4,020 - 4,040
# Process 0 running estimator on chunk 4040 - 4060
# Process 0 estimating PZ PDF for rows 4,040 - 4,060
# Process 0 running estimator on chunk 4060 - 4080
# Process 0 estimating PZ PDF for rows 4,060 - 4,080
# Process 0 running estimator on chunk 4080 - 4100
# Process 0 estimating PZ PDF for rows 4,080 - 4,100
# Process 0 running estimator on chunk 4100 - 4120
# Process 0 estimating PZ PDF for rows 4,100 - 4,120
# Process 0 running estimator on chunk 4120 - 4140
# Process 0 estimating PZ PDF for rows 4,120 - 4,140
# Process 0 running estimator on chunk 4140 - 4160
# Process 0 estimating PZ PDF for rows 4,140 - 4,160
# Process 0 running estimator on chunk 4160 - 4180
# Process 0 estimating PZ PDF for rows 4,160 - 4,180
# Process 0 running estimator on chunk 4180 - 4200
# Process 0 estimating PZ PDF for rows 4,180 - 4,200
# Process 0 running estimator on chunk 4200 - 4220
# Process 0 estimating PZ PDF for rows 4,200 - 4,220
# Process 0 running estimator on chunk 4220 - 4240
# Process 0 estimating PZ PDF for rows 4,220 - 4,240
# Process 0 running estimator on chunk 4240 - 4260
# Process 0 estimating PZ PDF for rows 4,240 - 4,260
# Process 0 running estimator on chunk 4260 - 4280
# Process 0 estimating PZ PDF for rows 4,260 - 4,280
# Process 0 running estimator on chunk 4280 - 4300
# Process 0 estimating PZ PDF for rows 4,280 - 4,300
# Process 0 running estimator on chunk 4300 - 4320
# Process 0 estimating PZ PDF for rows 4,300 - 4,320
# Process 0 running estimator on chunk 4320 - 4340
# Process 0 estimating PZ PDF for rows 4,320 - 4,340
# Process 0 running estimator on chunk 4340 - 4360
# Process 0 estimating PZ PDF for rows 4,340 - 4,360
# Process 0 running estimator on chunk 4360 - 4380
# Process 0 estimating PZ PDF for rows 4,360 - 4,380
# Process 0 running estimator on chunk 4380 - 4400
# Process 0 estimating PZ PDF for rows 4,380 - 4,400
# Process 0 running estimator on chunk 4400 - 4420
# Process 0 estimating PZ PDF for rows 4,400 - 4,420
# Process 0 running estimator on chunk 4420 - 4440
# Process 0 estimating PZ PDF for rows 4,420 - 4,440
# Process 0 running estimator on chunk 4440 - 4460
# Process 0 estimating PZ PDF for rows 4,440 - 4,460
# Process 0 running estimator on chunk 4460 - 4480
# Process 0 estimating PZ PDF for rows 4,460 - 4,480
# Process 0 running estimator on chunk 4480 - 4500
# Process 0 estimating PZ PDF for rows 4,480 - 4,500
# Process 0 running estimator on chunk 4500 - 4520
# Process 0 estimating PZ PDF for rows 4,500 - 4,520
# Process 0 running estimator on chunk 4520 - 4540
# Process 0 estimating PZ PDF for rows 4,520 - 4,540
# Process 0 running estimator on chunk 4540 - 4560
# Process 0 estimating PZ PDF for rows 4,540 - 4,560
# Process 0 running estimator on chunk 4560 - 4580
# Process 0 estimating PZ PDF for rows 4,560 - 4,580
# Process 0 running estimator on chunk 4580 - 4600
# Process 0 estimating PZ PDF for rows 4,580 - 4,600
# Process 0 running estimator on chunk 4600 - 4620
# Process 0 estimating PZ PDF for rows 4,600 - 4,620
# Process 0 running estimator on chunk 4620 - 4640
# Process 0 estimating PZ PDF for rows 4,620 - 4,640
# Process 0 running estimator on chunk 4640 - 4660
# Process 0 estimating PZ PDF for rows 4,640 - 4,660
# Process 0 running estimator on chunk 4660 - 4680
# Process 0 estimating PZ PDF for rows 4,660 - 4,680
# Process 0 running estimator on chunk 4680 - 4700
# Process 0 estimating PZ PDF for rows 4,680 - 4,700
# Process 0 running estimator on chunk 4700 - 4720
# Process 0 estimating PZ PDF for rows 4,700 - 4,720
# Process 0 running estimator on chunk 4720 - 4740
# Process 0 estimating PZ PDF for rows 4,720 - 4,740
# Process 0 running estimator on chunk 4740 - 4760
# Process 0 estimating PZ PDF for rows 4,740 - 4,760
# Process 0 running estimator on chunk 4760 - 4780
# Process 0 estimating PZ PDF for rows 4,760 - 4,780
# Process 0 running estimator on chunk 4780 - 4800
# Process 0 estimating PZ PDF for rows 4,780 - 4,800
# Process 0 running estimator on chunk 4800 - 4820
# Process 0 estimating PZ PDF for rows 4,800 - 4,820
# Process 0 running estimator on chunk 4820 - 4840
# Process 0 estimating PZ PDF for rows 4,820 - 4,840
# Process 0 running estimator on chunk 4840 - 4860
# Process 0 estimating PZ PDF for rows 4,840 - 4,860
# Process 0 running estimator on chunk 4860 - 4880
# Process 0 estimating PZ PDF for rows 4,860 - 4,880
# Process 0 running estimator on chunk 4880 - 4900
# Process 0 estimating PZ PDF for rows 4,880 - 4,900
# Process 0 running estimator on chunk 4900 - 4920
# Process 0 estimating PZ PDF for rows 4,900 - 4,920
# Process 0 running estimator on chunk 4920 - 4940
# Process 0 estimating PZ PDF for rows 4,920 - 4,940
# Process 0 running estimator on chunk 4940 - 4960
# Process 0 estimating PZ PDF for rows 4,940 - 4,960
# Process 0 running estimator on chunk 4960 - 4980
# Process 0 estimating PZ PDF for rows 4,960 - 4,980
# Process 0 running estimator on chunk 4980 - 5000
# Process 0 estimating PZ PDF for rows 4,980 - 5,000
# Process 0 running estimator on chunk 5000 - 5020
# Process 0 estimating PZ PDF for rows 5,000 - 5,020
# Process 0 running estimator on chunk 5020 - 5040
# Process 0 estimating PZ PDF for rows 5,020 - 5,040
# Process 0 running estimator on chunk 5040 - 5060
# Process 0 estimating PZ PDF for rows 5,040 - 5,060
# Process 0 running estimator on chunk 5060 - 5080
# Process 0 estimating PZ PDF for rows 5,060 - 5,080
# Process 0 running estimator on chunk 5080 - 5100
# Process 0 estimating PZ PDF for rows 5,080 - 5,100
# Process 0 running estimator on chunk 5100 - 5120
# Process 0 estimating PZ PDF for rows 5,100 - 5,120
# Process 0 running estimator on chunk 5120 - 5140
# Process 0 estimating PZ PDF for rows 5,120 - 5,140
# Process 0 running estimator on chunk 5140 - 5160
# Process 0 estimating PZ PDF for rows 5,140 - 5,160
# Process 0 running estimator on chunk 5160 - 5180
# Process 0 estimating PZ PDF for rows 5,160 - 5,180
# Process 0 running estimator on chunk 5180 - 5200
# Process 0 estimating PZ PDF for rows 5,180 - 5,200
# Process 0 running estimator on chunk 5200 - 5220
# Process 0 estimating PZ PDF for rows 5,200 - 5,220
# Process 0 running estimator on chunk 5220 - 5240
# Process 0 estimating PZ PDF for rows 5,220 - 5,240
# Process 0 running estimator on chunk 5240 - 5260
# Process 0 estimating PZ PDF for rows 5,240 - 5,260
# Process 0 running estimator on chunk 5260 - 5280
# Process 0 estimating PZ PDF for rows 5,260 - 5,280
# Process 0 running estimator on chunk 5280 - 5300
# Process 0 estimating PZ PDF for rows 5,280 - 5,300
# Process 0 running estimator on chunk 5300 - 5320
# Process 0 estimating PZ PDF for rows 5,300 - 5,320
# Process 0 running estimator on chunk 5320 - 5340
# Process 0 estimating PZ PDF for rows 5,320 - 5,340
# Process 0 running estimator on chunk 5340 - 5360
# Process 0 estimating PZ PDF for rows 5,340 - 5,360
# Process 0 running estimator on chunk 5360 - 5380
# Process 0 estimating PZ PDF for rows 5,360 - 5,380
# Process 0 running estimator on chunk 5380 - 5400
# Process 0 estimating PZ PDF for rows 5,380 - 5,400
# Process 0 running estimator on chunk 5400 - 5420
# Process 0 estimating PZ PDF for rows 5,400 - 5,420
# Process 0 running estimator on chunk 5420 - 5440
# Process 0 estimating PZ PDF for rows 5,420 - 5,440
# Process 0 running estimator on chunk 5440 - 5460
# Process 0 estimating PZ PDF for rows 5,440 - 5,460
# Process 0 running estimator on chunk 5460 - 5480
# Process 0 estimating PZ PDF for rows 5,460 - 5,480
# Process 0 running estimator on chunk 5480 - 5500
# Process 0 estimating PZ PDF for rows 5,480 - 5,500
# Process 0 running estimator on chunk 5500 - 5520
# Process 0 estimating PZ PDF for rows 5,500 - 5,520
# Process 0 running estimator on chunk 5520 - 5540
# Process 0 estimating PZ PDF for rows 5,520 - 5,540
# Process 0 running estimator on chunk 5540 - 5560
# Process 0 estimating PZ PDF for rows 5,540 - 5,560
# Process 0 running estimator on chunk 5560 - 5580
# Process 0 estimating PZ PDF for rows 5,560 - 5,580
# Process 0 running estimator on chunk 5580 - 5600
# Process 0 estimating PZ PDF for rows 5,580 - 5,600
# Process 0 running estimator on chunk 5600 - 5620
# Process 0 estimating PZ PDF for rows 5,600 - 5,620
# Process 0 running estimator on chunk 5620 - 5640
# Process 0 estimating PZ PDF for rows 5,620 - 5,640
# Process 0 running estimator on chunk 5640 - 5660
# Process 0 estimating PZ PDF for rows 5,640 - 5,660
# Process 0 running estimator on chunk 5660 - 5680
# Process 0 estimating PZ PDF for rows 5,660 - 5,680
# Process 0 running estimator on chunk 5680 - 5700
# Process 0 estimating PZ PDF for rows 5,680 - 5,700
# Process 0 running estimator on chunk 5700 - 5720
# Process 0 estimating PZ PDF for rows 5,700 - 5,720
# Process 0 running estimator on chunk 5720 - 5740
# Process 0 estimating PZ PDF for rows 5,720 - 5,740
# Process 0 running estimator on chunk 5740 - 5760
# Process 0 estimating PZ PDF for rows 5,740 - 5,760
# Process 0 running estimator on chunk 5760 - 5780
# Process 0 estimating PZ PDF for rows 5,760 - 5,780
# Process 0 running estimator on chunk 5780 - 5800
# Process 0 estimating PZ PDF for rows 5,780 - 5,800
# Process 0 running estimator on chunk 5800 - 5820
# Process 0 estimating PZ PDF for rows 5,800 - 5,820
# Process 0 running estimator on chunk 5820 - 5840
# Process 0 estimating PZ PDF for rows 5,820 - 5,840
# Process 0 running estimator on chunk 5840 - 5860
# Process 0 estimating PZ PDF for rows 5,840 - 5,860
# Process 0 running estimator on chunk 5860 - 5880
# Process 0 estimating PZ PDF for rows 5,860 - 5,880
# Process 0 running estimator on chunk 5880 - 5900
# Process 0 estimating PZ PDF for rows 5,880 - 5,900
# Process 0 running estimator on chunk 5900 - 5920
# Process 0 estimating PZ PDF for rows 5,900 - 5,920
# Process 0 running estimator on chunk 5920 - 5940
# Process 0 estimating PZ PDF for rows 5,920 - 5,940
# Process 0 running estimator on chunk 5940 - 5960
# Process 0 estimating PZ PDF for rows 5,940 - 5,960
# Process 0 running estimator on chunk 5960 - 5980
# Process 0 estimating PZ PDF for rows 5,960 - 5,980
# Process 0 running estimator on chunk 5980 - 6000
# Process 0 estimating PZ PDF for rows 5,980 - 6,000
# Process 0 running estimator on chunk 6000 - 6020
# Process 0 estimating PZ PDF for rows 6,000 - 6,020
# Process 0 running estimator on chunk 6020 - 6040
# Process 0 estimating PZ PDF for rows 6,020 - 6,040
# Process 0 running estimator on chunk 6040 - 6060
# Process 0 estimating PZ PDF for rows 6,040 - 6,060
# Process 0 running estimator on chunk 6060 - 6080
# Process 0 estimating PZ PDF for rows 6,060 - 6,080
# Process 0 running estimator on chunk 6080 - 6100
# Process 0 estimating PZ PDF for rows 6,080 - 6,100
# Process 0 running estimator on chunk 6100 - 6120
# Process 0 estimating PZ PDF for rows 6,100 - 6,120
# Process 0 running estimator on chunk 6120 - 6140
# Process 0 estimating PZ PDF for rows 6,120 - 6,140
# Process 0 running estimator on chunk 6140 - 6160
# Process 0 estimating PZ PDF for rows 6,140 - 6,160
# Process 0 running estimator on chunk 6160 - 6180
# Process 0 estimating PZ PDF for rows 6,160 - 6,180
# Process 0 running estimator on chunk 6180 - 6200
# Process 0 estimating PZ PDF for rows 6,180 - 6,200
# Process 0 running estimator on chunk 6200 - 6220
# Process 0 estimating PZ PDF for rows 6,200 - 6,220
# Process 0 running estimator on chunk 6220 - 6240
# Process 0 estimating PZ PDF for rows 6,220 - 6,240
# Process 0 running estimator on chunk 6240 - 6260
# Process 0 estimating PZ PDF for rows 6,240 - 6,260
# Process 0 running estimator on chunk 6260 - 6280
# Process 0 estimating PZ PDF for rows 6,260 - 6,280
# Process 0 running estimator on chunk 6280 - 6300
# Process 0 estimating PZ PDF for rows 6,280 - 6,300
# Process 0 running estimator on chunk 6300 - 6320
# Process 0 estimating PZ PDF for rows 6,300 - 6,320
# Process 0 running estimator on chunk 6320 - 6340
# Process 0 estimating PZ PDF for rows 6,320 - 6,340
# Process 0 running estimator on chunk 6340 - 6360
# Process 0 estimating PZ PDF for rows 6,340 - 6,360
# Process 0 running estimator on chunk 6360 - 6380
# Process 0 estimating PZ PDF for rows 6,360 - 6,380
# Process 0 running estimator on chunk 6380 - 6400
# Process 0 estimating PZ PDF for rows 6,380 - 6,400
# Process 0 running estimator on chunk 6400 - 6420
# Process 0 estimating PZ PDF for rows 6,400 - 6,420
# Process 0 running estimator on chunk 6420 - 6440
# Process 0 estimating PZ PDF for rows 6,420 - 6,440
# Process 0 running estimator on chunk 6440 - 6460
# Process 0 estimating PZ PDF for rows 6,440 - 6,460
# Process 0 running estimator on chunk 6460 - 6480
# Process 0 estimating PZ PDF for rows 6,460 - 6,480
# Process 0 running estimator on chunk 6480 - 6500
# Process 0 estimating PZ PDF for rows 6,480 - 6,500
# Process 0 running estimator on chunk 6500 - 6520
# Process 0 estimating PZ PDF for rows 6,500 - 6,520
# Process 0 running estimator on chunk 6520 - 6540
# Process 0 estimating PZ PDF for rows 6,520 - 6,540
# Process 0 running estimator on chunk 6540 - 6560
# Process 0 estimating PZ PDF for rows 6,540 - 6,560
# Process 0 running estimator on chunk 6560 - 6580
# Process 0 estimating PZ PDF for rows 6,560 - 6,580
# Process 0 running estimator on chunk 6580 - 6600
# Process 0 estimating PZ PDF for rows 6,580 - 6,600
# Process 0 running estimator on chunk 6600 - 6620
# Process 0 estimating PZ PDF for rows 6,600 - 6,620
# Process 0 running estimator on chunk 6620 - 6640
# Process 0 estimating PZ PDF for rows 6,620 - 6,640
# Process 0 running estimator on chunk 6640 - 6660
# Process 0 estimating PZ PDF for rows 6,640 - 6,660
# Process 0 running estimator on chunk 6660 - 6680
# Process 0 estimating PZ PDF for rows 6,660 - 6,680
# Process 0 running estimator on chunk 6680 - 6700
# Process 0 estimating PZ PDF for rows 6,680 - 6,700
# Process 0 running estimator on chunk 6700 - 6720
# Process 0 estimating PZ PDF for rows 6,700 - 6,720
# Process 0 running estimator on chunk 6720 - 6740
# Process 0 estimating PZ PDF for rows 6,720 - 6,740
# Process 0 running estimator on chunk 6740 - 6760
# Process 0 estimating PZ PDF for rows 6,740 - 6,760
# Process 0 running estimator on chunk 6760 - 6780
# Process 0 estimating PZ PDF for rows 6,760 - 6,780
# Process 0 running estimator on chunk 6780 - 6800
# Process 0 estimating PZ PDF for rows 6,780 - 6,800
# Process 0 running estimator on chunk 6800 - 6820
# Process 0 estimating PZ PDF for rows 6,800 - 6,820
# Process 0 running estimator on chunk 6820 - 6840
# Process 0 estimating PZ PDF for rows 6,820 - 6,840
# Process 0 running estimator on chunk 6840 - 6860
# Process 0 estimating PZ PDF for rows 6,840 - 6,860
# Process 0 running estimator on chunk 6860 - 6880
# Process 0 estimating PZ PDF for rows 6,860 - 6,880
# Process 0 running estimator on chunk 6880 - 6900
# Process 0 estimating PZ PDF for rows 6,880 - 6,900
# Process 0 running estimator on chunk 6900 - 6920
# Process 0 estimating PZ PDF for rows 6,900 - 6,920
# Process 0 running estimator on chunk 6920 - 6940
# Process 0 estimating PZ PDF for rows 6,920 - 6,940
# Process 0 running estimator on chunk 6940 - 6960
# Process 0 estimating PZ PDF for rows 6,940 - 6,960
# Process 0 running estimator on chunk 6960 - 6980
# Process 0 estimating PZ PDF for rows 6,960 - 6,980
# Process 0 running estimator on chunk 6980 - 7000
# Process 0 estimating PZ PDF for rows 6,980 - 7,000
# Process 0 running estimator on chunk 7000 - 7020
# Process 0 estimating PZ PDF for rows 7,000 - 7,020
# Process 0 running estimator on chunk 7020 - 7040
# Process 0 estimating PZ PDF for rows 7,020 - 7,040
# Process 0 running estimator on chunk 7040 - 7060
# Process 0 estimating PZ PDF for rows 7,040 - 7,060
# Process 0 running estimator on chunk 7060 - 7080
# Process 0 estimating PZ PDF for rows 7,060 - 7,080
# Process 0 running estimator on chunk 7080 - 7100
# Process 0 estimating PZ PDF for rows 7,080 - 7,100
# Process 0 running estimator on chunk 7100 - 7120
# Process 0 estimating PZ PDF for rows 7,100 - 7,120
# Process 0 running estimator on chunk 7120 - 7140
# Process 0 estimating PZ PDF for rows 7,120 - 7,140
# Process 0 running estimator on chunk 7140 - 7160
# Process 0 estimating PZ PDF for rows 7,140 - 7,160
# Process 0 running estimator on chunk 7160 - 7180
# Process 0 estimating PZ PDF for rows 7,160 - 7,180
# Process 0 running estimator on chunk 7180 - 7200
# Process 0 estimating PZ PDF for rows 7,180 - 7,200
# Process 0 running estimator on chunk 7200 - 7220
# Process 0 estimating PZ PDF for rows 7,200 - 7,220
# Process 0 running estimator on chunk 7220 - 7240
# Process 0 estimating PZ PDF for rows 7,220 - 7,240
# Process 0 running estimator on chunk 7240 - 7260
# Process 0 estimating PZ PDF for rows 7,240 - 7,260
# Process 0 running estimator on chunk 7260 - 7280
# Process 0 estimating PZ PDF for rows 7,260 - 7,280
# Process 0 running estimator on chunk 7280 - 7300
# Process 0 estimating PZ PDF for rows 7,280 - 7,300
# Process 0 running estimator on chunk 7300 - 7320
# Process 0 estimating PZ PDF for rows 7,300 - 7,320
# Process 0 running estimator on chunk 7320 - 7340
# Process 0 estimating PZ PDF for rows 7,320 - 7,340
# Process 0 running estimator on chunk 7340 - 7360
# Process 0 estimating PZ PDF for rows 7,340 - 7,360
# Process 0 running estimator on chunk 7360 - 7380
# Process 0 estimating PZ PDF for rows 7,360 - 7,380
# Process 0 running estimator on chunk 7380 - 7400
# Process 0 estimating PZ PDF for rows 7,380 - 7,400
# Process 0 running estimator on chunk 7400 - 7420
# Process 0 estimating PZ PDF for rows 7,400 - 7,420
# Process 0 running estimator on chunk 7420 - 7440
# Process 0 estimating PZ PDF for rows 7,420 - 7,440
# Process 0 running estimator on chunk 7440 - 7460
# Process 0 estimating PZ PDF for rows 7,440 - 7,460
# Process 0 running estimator on chunk 7460 - 7480
# Process 0 estimating PZ PDF for rows 7,460 - 7,480
# Process 0 running estimator on chunk 7480 - 7500
# Process 0 estimating PZ PDF for rows 7,480 - 7,500
# Process 0 running estimator on chunk 7500 - 7520
# Process 0 estimating PZ PDF for rows 7,500 - 7,520
# Process 0 running estimator on chunk 7520 - 7540
# Process 0 estimating PZ PDF for rows 7,520 - 7,540
# Process 0 running estimator on chunk 7540 - 7560
# Process 0 estimating PZ PDF for rows 7,540 - 7,560
# Process 0 running estimator on chunk 7560 - 7580
# Process 0 estimating PZ PDF for rows 7,560 - 7,580
# Process 0 running estimator on chunk 7580 - 7600
# Process 0 estimating PZ PDF for rows 7,580 - 7,600
# Process 0 running estimator on chunk 7600 - 7620
# Process 0 estimating PZ PDF for rows 7,600 - 7,620
# Process 0 running estimator on chunk 7620 - 7640
# Process 0 estimating PZ PDF for rows 7,620 - 7,640
# Process 0 running estimator on chunk 7640 - 7660
# Process 0 estimating PZ PDF for rows 7,640 - 7,660
# Process 0 running estimator on chunk 7660 - 7680
# Process 0 estimating PZ PDF for rows 7,660 - 7,680
# Process 0 running estimator on chunk 7680 - 7700
# Process 0 estimating PZ PDF for rows 7,680 - 7,700
# Process 0 running estimator on chunk 7700 - 7720
# Process 0 estimating PZ PDF for rows 7,700 - 7,720
# Process 0 running estimator on chunk 7720 - 7740
# Process 0 estimating PZ PDF for rows 7,720 - 7,740
# Process 0 running estimator on chunk 7740 - 7760
# Process 0 estimating PZ PDF for rows 7,740 - 7,760
# Process 0 running estimator on chunk 7760 - 7780
# Process 0 estimating PZ PDF for rows 7,760 - 7,780
# Process 0 running estimator on chunk 7780 - 7800
# Process 0 estimating PZ PDF for rows 7,780 - 7,800
# Process 0 running estimator on chunk 7800 - 7820
# Process 0 estimating PZ PDF for rows 7,800 - 7,820
# Process 0 running estimator on chunk 7820 - 7840
# Process 0 estimating PZ PDF for rows 7,820 - 7,840
# Process 0 running estimator on chunk 7840 - 7860
# Process 0 estimating PZ PDF for rows 7,840 - 7,860
# Process 0 running estimator on chunk 7860 - 7880
# Process 0 estimating PZ PDF for rows 7,860 - 7,880
# Process 0 running estimator on chunk 7880 - 7900
# Process 0 estimating PZ PDF for rows 7,880 - 7,900
# Process 0 running estimator on chunk 7900 - 7920
# Process 0 estimating PZ PDF for rows 7,900 - 7,920
# Process 0 running estimator on chunk 7920 - 7940
# Process 0 estimating PZ PDF for rows 7,920 - 7,940
# Process 0 running estimator on chunk 7940 - 7960
# Process 0 estimating PZ PDF for rows 7,940 - 7,960
# Process 0 running estimator on chunk 7960 - 7980
# Process 0 estimating PZ PDF for rows 7,960 - 7,980
# Process 0 running estimator on chunk 7980 - 8000
# Process 0 estimating PZ PDF for rows 7,980 - 8,000
# Process 0 running estimator on chunk 8000 - 8020
# Process 0 estimating PZ PDF for rows 8,000 - 8,020
# Process 0 running estimator on chunk 8020 - 8040
# Process 0 estimating PZ PDF for rows 8,020 - 8,040
# Process 0 running estimator on chunk 8040 - 8060
# Process 0 estimating PZ PDF for rows 8,040 - 8,060
# Process 0 running estimator on chunk 8060 - 8080
# Process 0 estimating PZ PDF for rows 8,060 - 8,080
# Process 0 running estimator on chunk 8080 - 8100
# Process 0 estimating PZ PDF for rows 8,080 - 8,100
# Process 0 running estimator on chunk 8100 - 8120
# Process 0 estimating PZ PDF for rows 8,100 - 8,120
# Process 0 running estimator on chunk 8120 - 8140
# Process 0 estimating PZ PDF for rows 8,120 - 8,140
# Process 0 running estimator on chunk 8140 - 8160
# Process 0 estimating PZ PDF for rows 8,140 - 8,160
# Process 0 running estimator on chunk 8160 - 8180
# Process 0 estimating PZ PDF for rows 8,160 - 8,180
# Process 0 running estimator on chunk 8180 - 8200
# Process 0 estimating PZ PDF for rows 8,180 - 8,200
# Process 0 running estimator on chunk 8200 - 8220
# Process 0 estimating PZ PDF for rows 8,200 - 8,220
# Process 0 running estimator on chunk 8220 - 8240
# Process 0 estimating PZ PDF for rows 8,220 - 8,240
# Process 0 running estimator on chunk 8240 - 8260
# Process 0 estimating PZ PDF for rows 8,240 - 8,260
# Process 0 running estimator on chunk 8260 - 8280
# Process 0 estimating PZ PDF for rows 8,260 - 8,280
# Process 0 running estimator on chunk 8280 - 8300
# Process 0 estimating PZ PDF for rows 8,280 - 8,300
# Process 0 running estimator on chunk 8300 - 8320
# Process 0 estimating PZ PDF for rows 8,300 - 8,320
# Process 0 running estimator on chunk 8320 - 8340
# Process 0 estimating PZ PDF for rows 8,320 - 8,340
# Process 0 running estimator on chunk 8340 - 8360
# Process 0 estimating PZ PDF for rows 8,340 - 8,360
# Process 0 running estimator on chunk 8360 - 8380
# Process 0 estimating PZ PDF for rows 8,360 - 8,380
# Process 0 running estimator on chunk 8380 - 8400
# Process 0 estimating PZ PDF for rows 8,380 - 8,400
# Process 0 running estimator on chunk 8400 - 8420
# Process 0 estimating PZ PDF for rows 8,400 - 8,420
# Process 0 running estimator on chunk 8420 - 8440
# Process 0 estimating PZ PDF for rows 8,420 - 8,440
# Process 0 running estimator on chunk 8440 - 8460
# Process 0 estimating PZ PDF for rows 8,440 - 8,460
# Process 0 running estimator on chunk 8460 - 8480
# Process 0 estimating PZ PDF for rows 8,460 - 8,480
# Process 0 running estimator on chunk 8480 - 8500
# Process 0 estimating PZ PDF for rows 8,480 - 8,500
# Process 0 running estimator on chunk 8500 - 8520
# Process 0 estimating PZ PDF for rows 8,500 - 8,520
# Process 0 running estimator on chunk 8520 - 8540
# Process 0 estimating PZ PDF for rows 8,520 - 8,540
# Process 0 running estimator on chunk 8540 - 8560
# Process 0 estimating PZ PDF for rows 8,540 - 8,560
# Process 0 running estimator on chunk 8560 - 8580
# Process 0 estimating PZ PDF for rows 8,560 - 8,580
# Process 0 running estimator on chunk 8580 - 8600
# Process 0 estimating PZ PDF for rows 8,580 - 8,600
# Process 0 running estimator on chunk 8600 - 8620
# Process 0 estimating PZ PDF for rows 8,600 - 8,620
# Process 0 running estimator on chunk 8620 - 8640
# Process 0 estimating PZ PDF for rows 8,620 - 8,640
# Process 0 running estimator on chunk 8640 - 8660
# Process 0 estimating PZ PDF for rows 8,640 - 8,660
# Process 0 running estimator on chunk 8660 - 8680
# Process 0 estimating PZ PDF for rows 8,660 - 8,680
# Process 0 running estimator on chunk 8680 - 8700
# Process 0 estimating PZ PDF for rows 8,680 - 8,700
# Process 0 running estimator on chunk 8700 - 8720
# Process 0 estimating PZ PDF for rows 8,700 - 8,720
# Process 0 running estimator on chunk 8720 - 8740
# Process 0 estimating PZ PDF for rows 8,720 - 8,740
# Process 0 running estimator on chunk 8740 - 8760
# Process 0 estimating PZ PDF for rows 8,740 - 8,760
# Process 0 running estimator on chunk 8760 - 8780
# Process 0 estimating PZ PDF for rows 8,760 - 8,780
# Process 0 running estimator on chunk 8780 - 8800
# Process 0 estimating PZ PDF for rows 8,780 - 8,800
# Process 0 running estimator on chunk 8800 - 8820
# Process 0 estimating PZ PDF for rows 8,800 - 8,820
# Process 0 running estimator on chunk 8820 - 8840
# Process 0 estimating PZ PDF for rows 8,820 - 8,840
# Process 0 running estimator on chunk 8840 - 8860
# Process 0 estimating PZ PDF for rows 8,840 - 8,860
# Process 0 running estimator on chunk 8860 - 8880
# Process 0 estimating PZ PDF for rows 8,860 - 8,880
# Process 0 running estimator on chunk 8880 - 8900
# Process 0 estimating PZ PDF for rows 8,880 - 8,900
# Process 0 running estimator on chunk 8900 - 8920
# Process 0 estimating PZ PDF for rows 8,900 - 8,920
# Process 0 running estimator on chunk 8920 - 8940
# Process 0 estimating PZ PDF for rows 8,920 - 8,940
# Process 0 running estimator on chunk 8940 - 8960
# Process 0 estimating PZ PDF for rows 8,940 - 8,960
# Process 0 running estimator on chunk 8960 - 8980
# Process 0 estimating PZ PDF for rows 8,960 - 8,980
# Process 0 running estimator on chunk 8980 - 9000
# Process 0 estimating PZ PDF for rows 8,980 - 9,000
# Process 0 running estimator on chunk 9000 - 9020
# Process 0 estimating PZ PDF for rows 9,000 - 9,020
# Process 0 running estimator on chunk 9020 - 9040
# Process 0 estimating PZ PDF for rows 9,020 - 9,040
# Process 0 running estimator on chunk 9040 - 9060
# Process 0 estimating PZ PDF for rows 9,040 - 9,060
# Process 0 running estimator on chunk 9060 - 9080
# Process 0 estimating PZ PDF for rows 9,060 - 9,080
# Process 0 running estimator on chunk 9080 - 9100
# Process 0 estimating PZ PDF for rows 9,080 - 9,100
# Process 0 running estimator on chunk 9100 - 9120
# Process 0 estimating PZ PDF for rows 9,100 - 9,120
# Process 0 running estimator on chunk 9120 - 9140
# Process 0 estimating PZ PDF for rows 9,120 - 9,140
# Process 0 running estimator on chunk 9140 - 9160
# Process 0 estimating PZ PDF for rows 9,140 - 9,160
# Process 0 running estimator on chunk 9160 - 9180
# Process 0 estimating PZ PDF for rows 9,160 - 9,180
# Process 0 running estimator on chunk 9180 - 9200
# Process 0 estimating PZ PDF for rows 9,180 - 9,200
# Process 0 running estimator on chunk 9200 - 9220
# Process 0 estimating PZ PDF for rows 9,200 - 9,220
# Process 0 running estimator on chunk 9220 - 9240
# Process 0 estimating PZ PDF for rows 9,220 - 9,240
# Process 0 running estimator on chunk 9240 - 9260
# Process 0 estimating PZ PDF for rows 9,240 - 9,260
# Process 0 running estimator on chunk 9260 - 9280
# Process 0 estimating PZ PDF for rows 9,260 - 9,280
# Process 0 running estimator on chunk 9280 - 9300
# Process 0 estimating PZ PDF for rows 9,280 - 9,300
# Process 0 running estimator on chunk 9300 - 9320
# Process 0 estimating PZ PDF for rows 9,300 - 9,320
# Process 0 running estimator on chunk 9320 - 9340
# Process 0 estimating PZ PDF for rows 9,320 - 9,340
# Process 0 running estimator on chunk 9340 - 9360
# Process 0 estimating PZ PDF for rows 9,340 - 9,360
# Process 0 running estimator on chunk 9360 - 9380
# Process 0 estimating PZ PDF for rows 9,360 - 9,380
# Process 0 running estimator on chunk 9380 - 9400
# Process 0 estimating PZ PDF for rows 9,380 - 9,400
# Process 0 running estimator on chunk 9400 - 9420
# Process 0 estimating PZ PDF for rows 9,400 - 9,420
# Process 0 running estimator on chunk 9420 - 9440
# Process 0 estimating PZ PDF for rows 9,420 - 9,440
# Process 0 running estimator on chunk 9440 - 9460
# Process 0 estimating PZ PDF for rows 9,440 - 9,460
# Process 0 running estimator on chunk 9460 - 9480
# Process 0 estimating PZ PDF for rows 9,460 - 9,480
# Process 0 running estimator on chunk 9480 - 9500
# Process 0 estimating PZ PDF for rows 9,480 - 9,500
# Process 0 running estimator on chunk 9500 - 9520
# Process 0 estimating PZ PDF for rows 9,500 - 9,520
# Process 0 running estimator on chunk 9520 - 9540
# Process 0 estimating PZ PDF for rows 9,520 - 9,540
# Process 0 running estimator on chunk 9540 - 9560
# Process 0 estimating PZ PDF for rows 9,540 - 9,560
# Process 0 running estimator on chunk 9560 - 9580
# Process 0 estimating PZ PDF for rows 9,560 - 9,580
# Process 0 running estimator on chunk 9580 - 9600
# Process 0 estimating PZ PDF for rows 9,580 - 9,600
# Process 0 running estimator on chunk 9600 - 9620
# Process 0 estimating PZ PDF for rows 9,600 - 9,620
# Process 0 running estimator on chunk 9620 - 9640
# Process 0 estimating PZ PDF for rows 9,620 - 9,640
# ...
# Process 0 estimating PZ PDF for rows 37,460 - 37,480
# Process 0 running estimator on chunk 37480 - 37500
# Process 0 estimating PZ PDF for rows 37,480 - 37,500
# Process 0 running estimator on chunk 37500 - 37520
# Process 0 estimating PZ PDF for rows 37,500 - 37,520
# Process 0 running estimator on chunk 37520 - 37540
# Process 0 estimating PZ PDF for rows 37,520 - 37,540
# Process 0 running estimator on chunk 37540 - 37560
# Process 0 estimating PZ PDF for rows 37,540 - 37,560
# Process 0 running estimator on chunk 37560 - 37580
# Process 0 estimating PZ PDF for rows 37,560 - 37,580
# Process 0 running estimator on chunk 37580 - 37600
# Process 0 estimating PZ PDF for rows 37,580 - 37,600
# Process 0 running estimator on chunk 37600 - 37620
# Process 0 estimating PZ PDF for rows 37,600 - 37,620
# Process 0 running estimator on chunk 37620 - 37640
# Process 0 estimating PZ PDF for rows 37,620 - 37,640
# Process 0 running estimator on chunk 37640 - 37660
# Process 0 estimating PZ PDF for rows 37,640 - 37,660
# Process 0 running estimator on chunk 37660 - 37680
# Process 0 estimating PZ PDF for rows 37,660 - 37,680
# Process 0 running estimator on chunk 37680 - 37700
# Process 0 estimating PZ PDF for rows 37,680 - 37,700
# Process 0 running estimator on chunk 37700 - 37720
# Process 0 estimating PZ PDF for rows 37,700 - 37,720
# Process 0 running estimator on chunk 37720 - 37740
# Process 0 estimating PZ PDF for rows 37,720 - 37,740
# Process 0 running estimator on chunk 37740 - 37760
# Process 0 estimating PZ PDF for rows 37,740 - 37,760
# Process 0 running estimator on chunk 37760 - 37780
# Process 0 estimating PZ PDF for rows 37,760 - 37,780
# Process 0 running estimator on chunk 37780 - 37800
# Process 0 estimating PZ PDF for rows 37,780 - 37,800
# Process 0 running estimator on chunk 37800 - 37820
# Process 0 estimating PZ PDF for rows 37,800 - 37,820
# Process 0 running estimator on chunk 37820 - 37840
# Process 0 estimating PZ PDF for rows 37,820 - 37,840
# Process 0 running estimator on chunk 37840 - 37860
# Process 0 estimating PZ PDF for rows 37,840 - 37,860
# Process 0 running estimator on chunk 37860 - 37880
# Process 0 estimating PZ PDF for rows 37,860 - 37,880
# Process 0 running estimator on chunk 37880 - 37900
# Process 0 estimating PZ PDF for rows 37,880 - 37,900
# Process 0 running estimator on chunk 37900 - 37920
# Process 0 estimating PZ PDF for rows 37,900 - 37,920
# Process 0 running estimator on chunk 37920 - 37940
# Process 0 estimating PZ PDF for rows 37,920 - 37,940
# Process 0 running estimator on chunk 37940 - 37960
# Process 0 estimating PZ PDF for rows 37,940 - 37,960
# Process 0 running estimator on chunk 37960 - 37980
# Process 0 estimating PZ PDF for rows 37,960 - 37,980
# Process 0 running estimator on chunk 37980 - 38000
# Process 0 estimating PZ PDF for rows 37,980 - 38,000
# Process 0 running estimator on chunk 38000 - 38020
# Process 0 estimating PZ PDF for rows 38,000 - 38,020
# Process 0 running estimator on chunk 38020 - 38040
# Process 0 estimating PZ PDF for rows 38,020 - 38,040
# Process 0 running estimator on chunk 38040 - 38060
# Process 0 estimating PZ PDF for rows 38,040 - 38,060
# Process 0 running estimator on chunk 38060 - 38080
# Process 0 estimating PZ PDF for rows 38,060 - 38,080
# Process 0 running estimator on chunk 38080 - 38100
# Process 0 estimating PZ PDF for rows 38,080 - 38,100
# Process 0 running estimator on chunk 38100 - 38120
# Process 0 estimating PZ PDF for rows 38,100 - 38,120
# Process 0 running estimator on chunk 38120 - 38140
# Process 0 estimating PZ PDF for rows 38,120 - 38,140
# Process 0 running estimator on chunk 38140 - 38160
# Process 0 estimating PZ PDF for rows 38,140 - 38,160
# Process 0 running estimator on chunk 38160 - 38180
# Process 0 estimating PZ PDF for rows 38,160 - 38,180
# Process 0 running estimator on chunk 38180 - 38200
# Process 0 estimating PZ PDF for rows 38,180 - 38,200
# Process 0 running estimator on chunk 38200 - 38220
# Process 0 estimating PZ PDF for rows 38,200 - 38,220
# Process 0 running estimator on chunk 38220 - 38240
# Process 0 estimating PZ PDF for rows 38,220 - 38,240
# Process 0 running estimator on chunk 38240 - 38260
# Process 0 estimating PZ PDF for rows 38,240 - 38,260
# Process 0 running estimator on chunk 38260 - 38280
# Process 0 estimating PZ PDF for rows 38,260 - 38,280
# Process 0 running estimator on chunk 38280 - 38300
# Process 0 estimating PZ PDF for rows 38,280 - 38,300
# Process 0 running estimator on chunk 38300 - 38320
# Process 0 estimating PZ PDF for rows 38,300 - 38,320
# Process 0 running estimator on chunk 38320 - 38340
# Process 0 estimating PZ PDF for rows 38,320 - 38,340
# Process 0 running estimator on chunk 38340 - 38360
# Process 0 estimating PZ PDF for rows 38,340 - 38,360
# Process 0 running estimator on chunk 38360 - 38380
# Process 0 estimating PZ PDF for rows 38,360 - 38,380
# Process 0 running estimator on chunk 38380 - 38400
# Process 0 estimating PZ PDF for rows 38,380 - 38,400
# Process 0 running estimator on chunk 38400 - 38420
# Process 0 estimating PZ PDF for rows 38,400 - 38,420
# Process 0 running estimator on chunk 38420 - 38440
# Process 0 estimating PZ PDF for rows 38,420 - 38,440
# Process 0 running estimator on chunk 38440 - 38460
# Process 0 estimating PZ PDF for rows 38,440 - 38,460
# Process 0 running estimator on chunk 38460 - 38480
# Process 0 estimating PZ PDF for rows 38,460 - 38,480
# Process 0 running estimator on chunk 38480 - 38500
# Process 0 estimating PZ PDF for rows 38,480 - 38,500
# Process 0 running estimator on chunk 38500 - 38520
# Process 0 estimating PZ PDF for rows 38,500 - 38,520
# Process 0 running estimator on chunk 38520 - 38540
# Process 0 estimating PZ PDF for rows 38,520 - 38,540
# Process 0 running estimator on chunk 38540 - 38560
# Process 0 estimating PZ PDF for rows 38,540 - 38,560
# Process 0 running estimator on chunk 38560 - 38580
# Process 0 estimating PZ PDF for rows 38,560 - 38,580
# Process 0 running estimator on chunk 38580 - 38600
# Process 0 estimating PZ PDF for rows 38,580 - 38,600
# Process 0 running estimator on chunk 38600 - 38620
# Process 0 estimating PZ PDF for rows 38,600 - 38,620
# Process 0 running estimator on chunk 38620 - 38640
# Process 0 estimating PZ PDF for rows 38,620 - 38,640
# Process 0 running estimator on chunk 38640 - 38660
# Process 0 estimating PZ PDF for rows 38,640 - 38,660
# Process 0 running estimator on chunk 38660 - 38680
# Process 0 estimating PZ PDF for rows 38,660 - 38,680
# Process 0 running estimator on chunk 38680 - 38700
# Process 0 estimating PZ PDF for rows 38,680 - 38,700
# Process 0 running estimator on chunk 38700 - 38720
# Process 0 estimating PZ PDF for rows 38,700 - 38,720
# Process 0 running estimator on chunk 38720 - 38740
# Process 0 estimating PZ PDF for rows 38,720 - 38,740
# Process 0 running estimator on chunk 38740 - 38760
# Process 0 estimating PZ PDF for rows 38,740 - 38,760
# Process 0 running estimator on chunk 38760 - 38780
# Process 0 estimating PZ PDF for rows 38,760 - 38,780
# Process 0 running estimator on chunk 38780 - 38800
# Process 0 estimating PZ PDF for rows 38,780 - 38,800
# Process 0 running estimator on chunk 38800 - 38820
# Process 0 estimating PZ PDF for rows 38,800 - 38,820
# Process 0 running estimator on chunk 38820 - 38840
# Process 0 estimating PZ PDF for rows 38,820 - 38,840
# Process 0 running estimator on chunk 38840 - 38860
# Process 0 estimating PZ PDF for rows 38,840 - 38,860
# Process 0 running estimator on chunk 38860 - 38880
# Process 0 estimating PZ PDF for rows 38,860 - 38,880
# Process 0 running estimator on chunk 38880 - 38900
# Process 0 estimating PZ PDF for rows 38,880 - 38,900
# Process 0 running estimator on chunk 38900 - 38920
# Process 0 estimating PZ PDF for rows 38,900 - 38,920
# Process 0 running estimator on chunk 38920 - 38940
# Process 0 estimating PZ PDF for rows 38,920 - 38,940
# Process 0 running estimator on chunk 38940 - 38960
# Process 0 estimating PZ PDF for rows 38,940 - 38,960
# Process 0 running estimator on chunk 38960 - 38980
# Process 0 estimating PZ PDF for rows 38,960 - 38,980
# Process 0 running estimator on chunk 38980 - 39000
# Process 0 estimating PZ PDF for rows 38,980 - 39,000
# Process 0 running estimator on chunk 39000 - 39020
# Process 0 estimating PZ PDF for rows 39,000 - 39,020
# Process 0 running estimator on chunk 39020 - 39040
# Process 0 estimating PZ PDF for rows 39,020 - 39,040
# Process 0 running estimator on chunk 39040 - 39060
# Process 0 estimating PZ PDF for rows 39,040 - 39,060
# Process 0 running estimator on chunk 39060 - 39080
# Process 0 estimating PZ PDF for rows 39,060 - 39,080
# Process 0 running estimator on chunk 39080 - 39100
# Process 0 estimating PZ PDF for rows 39,080 - 39,100
# Process 0 running estimator on chunk 39100 - 39120
# Process 0 estimating PZ PDF for rows 39,100 - 39,120
# Process 0 running estimator on chunk 39120 - 39140
# Process 0 estimating PZ PDF for rows 39,120 - 39,140
# Process 0 running estimator on chunk 39140 - 39160
# Process 0 estimating PZ PDF for rows 39,140 - 39,160
# Process 0 running estimator on chunk 39160 - 39180
# Process 0 estimating PZ PDF for rows 39,160 - 39,180
# Process 0 running estimator on chunk 39180 - 39200
# Process 0 estimating PZ PDF for rows 39,180 - 39,200
# Process 0 running estimator on chunk 39200 - 39220
# Process 0 estimating PZ PDF for rows 39,200 - 39,220
# Process 0 running estimator on chunk 39220 - 39240
# Process 0 estimating PZ PDF for rows 39,220 - 39,240
# Process 0 running estimator on chunk 39240 - 39260
# Process 0 estimating PZ PDF for rows 39,240 - 39,260
# Process 0 running estimator on chunk 39260 - 39280
# Process 0 estimating PZ PDF for rows 39,260 - 39,280
# Process 0 running estimator on chunk 39280 - 39300
# Process 0 estimating PZ PDF for rows 39,280 - 39,300
# Process 0 running estimator on chunk 39300 - 39320
# Process 0 estimating PZ PDF for rows 39,300 - 39,320
# Process 0 running estimator on chunk 39320 - 39340
# Process 0 estimating PZ PDF for rows 39,320 - 39,340
# Process 0 running estimator on chunk 39340 - 39360
# Process 0 estimating PZ PDF for rows 39,340 - 39,360
# Process 0 running estimator on chunk 39360 - 39380
# Process 0 estimating PZ PDF for rows 39,360 - 39,380
# Process 0 running estimator on chunk 39380 - 39400
# Process 0 estimating PZ PDF for rows 39,380 - 39,400
# Process 0 running estimator on chunk 39400 - 39420
# Process 0 estimating PZ PDF for rows 39,400 - 39,420
# Process 0 running estimator on chunk 39420 - 39440
# Process 0 estimating PZ PDF for rows 39,420 - 39,440
# Process 0 running estimator on chunk 39440 - 39460
# Process 0 estimating PZ PDF for rows 39,440 - 39,460
# Process 0 running estimator on chunk 39460 - 39480
# Process 0 estimating PZ PDF for rows 39,460 - 39,480
# Process 0 running estimator on chunk 39480 - 39500
# Process 0 estimating PZ PDF for rows 39,480 - 39,500
# Process 0 running estimator on chunk 39500 - 39520
# Process 0 estimating PZ PDF for rows 39,500 - 39,520
# Process 0 running estimator on chunk 39520 - 39540
# Process 0 estimating PZ PDF for rows 39,520 - 39,540
# Process 0 running estimator on chunk 39540 - 39560
# Process 0 estimating PZ PDF for rows 39,540 - 39,560
# Process 0 running estimator on chunk 39560 - 39580
# Process 0 estimating PZ PDF for rows 39,560 - 39,580
# Process 0 running estimator on chunk 39580 - 39600
# Process 0 estimating PZ PDF for rows 39,580 - 39,600
# Process 0 running estimator on chunk 39600 - 39620
# Process 0 estimating PZ PDF for rows 39,600 - 39,620
# Process 0 running estimator on chunk 39620 - 39640
# Process 0 estimating PZ PDF for rows 39,620 - 39,640
# Process 0 running estimator on chunk 39640 - 39660
# Process 0 estimating PZ PDF for rows 39,640 - 39,660
# Process 0 running estimator on chunk 39660 - 39680
# Process 0 estimating PZ PDF for rows 39,660 - 39,680
# Process 0 running estimator on chunk 39680 - 39700
# Process 0 estimating PZ PDF for rows 39,680 - 39,700
# Process 0 running estimator on chunk 39700 - 39720
# Process 0 estimating PZ PDF for rows 39,700 - 39,720
# Process 0 running estimator on chunk 39720 - 39740
# Process 0 estimating PZ PDF for rows 39,720 - 39,740
# Process 0 running estimator on chunk 39740 - 39760
# Process 0 estimating PZ PDF for rows 39,740 - 39,760
# Process 0 running estimator on chunk 39760 - 39780
# Process 0 estimating PZ PDF for rows 39,760 - 39,780
# Process 0 running estimator on chunk 39780 - 39800
# Process 0 estimating PZ PDF for rows 39,780 - 39,800
# Process 0 running estimator on chunk 39800 - 39820
# Process 0 estimating PZ PDF for rows 39,800 - 39,820
# Process 0 running estimator on chunk 39820 - 39840
# Process 0 estimating PZ PDF for rows 39,820 - 39,840
# Process 0 running estimator on chunk 39840 - 39860
# Process 0 estimating PZ PDF for rows 39,840 - 39,860
# Process 0 running estimator on chunk 39860 - 39880
# Process 0 estimating PZ PDF for rows 39,860 - 39,880
# Process 0 running estimator on chunk 39880 - 39900
# Process 0 estimating PZ PDF for rows 39,880 - 39,900
# Process 0 running estimator on chunk 39900 - 39920
# Process 0 estimating PZ PDF for rows 39,900 - 39,920
# Process 0 running estimator on chunk 39920 - 39940
# Process 0 estimating PZ PDF for rows 39,920 - 39,940
# Process 0 running estimator on chunk 39940 - 39960
# Process 0 estimating PZ PDF for rows 39,940 - 39,960
# Process 0 running estimator on chunk 39960 - 39980
# Process 0 estimating PZ PDF for rows 39,960 - 39,980
# Process 0 running estimator on chunk 39980 - 40000
# Process 0 estimating PZ PDF for rows 39,980 - 40,000
# Process 0 running estimator on chunk 40000 - 40020
# Process 0 estimating PZ PDF for rows 40,000 - 40,020
# Process 0 running estimator on chunk 40020 - 40040
# Process 0 estimating PZ PDF for rows 40,020 - 40,040
# Process 0 running estimator on chunk 40040 - 40060
# Process 0 estimating PZ PDF for rows 40,040 - 40,060
# Process 0 running estimator on chunk 40060 - 40080
# Process 0 estimating PZ PDF for rows 40,060 - 40,080
# Process 0 running estimator on chunk 40080 - 40100
# Process 0 estimating PZ PDF for rows 40,080 - 40,100
# Process 0 running estimator on chunk 40100 - 40120
# Process 0 estimating PZ PDF for rows 40,100 - 40,120
# Process 0 running estimator on chunk 40120 - 40140
# Process 0 estimating PZ PDF for rows 40,120 - 40,140
# Process 0 running estimator on chunk 40140 - 40160
# Process 0 estimating PZ PDF for rows 40,140 - 40,160
# Process 0 running estimator on chunk 40160 - 40180
# Process 0 estimating PZ PDF for rows 40,160 - 40,180
# Process 0 running estimator on chunk 40180 - 40200
# Process 0 estimating PZ PDF for rows 40,180 - 40,200
# Process 0 running estimator on chunk 40200 - 40220
# Process 0 estimating PZ PDF for rows 40,200 - 40,220
# Process 0 running estimator on chunk 40220 - 40240
# Process 0 estimating PZ PDF for rows 40,220 - 40,240
# Process 0 running estimator on chunk 40240 - 40260
# Process 0 estimating PZ PDF for rows 40,240 - 40,260
# Process 0 running estimator on chunk 40260 - 40280
# Process 0 estimating PZ PDF for rows 40,260 - 40,280
# Process 0 running estimator on chunk 40280 - 40300
# Process 0 estimating PZ PDF for rows 40,280 - 40,300
# Process 0 running estimator on chunk 40300 - 40320
# Process 0 estimating PZ PDF for rows 40,300 - 40,320
# Process 0 running estimator on chunk 40320 - 40340
# Process 0 estimating PZ PDF for rows 40,320 - 40,340
# Process 0 running estimator on chunk 40340 - 40360
# Process 0 estimating PZ PDF for rows 40,340 - 40,360
# Process 0 running estimator on chunk 40360 - 40380
# Process 0 estimating PZ PDF for rows 40,360 - 40,380
# Process 0 running estimator on chunk 40380 - 40400
# Process 0 estimating PZ PDF for rows 40,380 - 40,400
# Process 0 running estimator on chunk 40400 - 40420
# Process 0 estimating PZ PDF for rows 40,400 - 40,420
# Process 0 running estimator on chunk 40420 - 40440
# Process 0 estimating PZ PDF for rows 40,420 - 40,440
# Process 0 running estimator on chunk 40440 - 40460
# Process 0 estimating PZ PDF for rows 40,440 - 40,460
# Process 0 running estimator on chunk 40460 - 40480
# Process 0 estimating PZ PDF for rows 40,460 - 40,480
# Process 0 running estimator on chunk 40480 - 40500
# Process 0 estimating PZ PDF for rows 40,480 - 40,500
# Process 0 running estimator on chunk 40500 - 40520
# Process 0 estimating PZ PDF for rows 40,500 - 40,520
# Process 0 running estimator on chunk 40520 - 40534
# Process 0 estimating PZ PDF for rows 40,520 - 40,534

# %%
result = output_fzb()

# %%
result.write_to(f'/home/iago/ic_cosmo/results/results_DP02_{fraction}_{reg}_i_{round(limits[3],1)}.hdf5')

# %% [markdown]
# # Results
#
# You can analyze the results simply by inserting the directory path !!!

# %%
path = '/home/iago/ic_cosmo'#os.getcwd() # you can change this to the path to git file in your local

# %% [markdown]
# ## Functions
#
# Some of this functions came from LSST github

# %% [markdown]
# ### old_metrics_table

# %%
def old_metrics_table(photoz, ztrue, name="", show_dc1=True):
    rows = ["|Metric |", "|:---|", "|scatter |", "|bias |", "|outlier rate |"]
    sigma_iqr, bias, frac, sigma_mad = old_metrics(photoz, ztrue)
    rows[0] += f"{name} |"
    rows[1] += "---:|"
    rows[2] += f"{sigma_iqr:11.4f} |"
    rows[3] += f"{bias:11.5f} |"
    rows[4] += f"{frac:11.3f} |"
    if show_dc1:
        rows[0] += "DC1 paper"
        rows[1] += "---:"
        rows[2] += f"  0.0154"
        rows[3] += f" -0.00027"
        rows[4] += f"  0.020"
    table = ("\n").join(rows)
    return Markdown(table)

# %%
def old_metrics(photoz, ztrue):
    point = EvaluatePointStats(photoz, ztrue)
    sigma_iqr = point.CalculateSigmaIQR()
    bias = point.CalculateBias()
    frac = point.CalculateOutlierRate()
    sigma_mad = point.CalculateSigmaMAD()
    return sigma_iqr, bias, frac, sigma_mad

# %%
class EvaluatePointStats(object):
    """Copied from PZDC1paper repo. Adapted to remove the cut based on magnitude."""

    def __init__(self, pzvec, szvec):
        """An object that takes in the vectors of the point photo-z
        the spec-z, and the i-band magnitudes for calculating the
        point statistics
        Parameters:
        pzvec: Numpy 1d array of the point photo-z values
        szvec: Numpy 1d array of the spec-z values
        magvec: Numpy 1d array of the i-band magnitudes
        imagcut: float: i-band magnitude cut for the sample
        Calculates:
        ez_all: (pz-sz)/(1+sz), the quantity will be useful for calculating statistics
        ez_magcut: ez sample trimmed with imagcut
        """
        self.pzs = pzvec
        self.szs = szvec
        ez = (pzvec - szvec) / (1. + szvec)
        self.ez_all = ez

    def CalculateSigmaIQR(self):
        """Calculate the width of the e_z distribution
        using the Interquartile range
        Parameters:
        imagcut: float: i-band magnitude cut for the sample
        Returns:
        sigma_IQR_all float: width of ez distribution for full sample
        sigma_IQR_magcut float: width of ez distribution for magcut sample
        """
        x75, x25 = np.percentile(self.ez_all, [75., 25.])
        iqr_all = x75 - x25
        sigma_iqr_all = iqr_all / 1.349
        self.sigma_iqr_all = sigma_iqr_all

        return sigma_iqr_all

    def CalculateBias(self):
        """calculates the bias of the ez and ez_magcut samples.  In
        keeping with the Science Book, this is just the median of the
        ez values
        Returns:
        bias_all: median of the full ez sample
        bias_magcut: median of the magcut ez sample
        """
        bias_all = np.median(self.ez_all)
        return bias_all

    def CalculateOutlierRate(self):
        """Calculates the catastrophic outlier rate, defined in the
        Science Book as the number of galaxies with ez larger than
        max(0.06,3sigma).  This keeps the fraction reasonable when
        sigma is very small.
        Returns:
        frac_all: fraction of catastrophic outliers for full sample
        frac_magcut: fraction of catastrophic outliers for magcut
        sample
        """
        num_all = len(self.ez_all)
        threesig_all = 3.0 * self.sigma_iqr_all
        cutcriterion_all = np.maximum(0.06, threesig_all)
        mask_all = (self.ez_all > np.fabs(cutcriterion_all))
        outlier_all = np.sum(mask_all)
        frac_all = float(outlier_all) / float(num_all)
        return frac_all

    def CalculateSigmaMAD(self):
        """Function to calculate median absolute deviation and sigma
        based on MAD (just scaled up by 1.4826) for the full and
        magnitude trimmed samples of ez values
        Returns:
        sigma_mad_all: sigma_MAD for full sample
        sigma_mad_cut: sigma_MAD for the magnitude cut sample
        """
        tmpmed_all = np.median(self.ez_all)
        tmpx_all = np.fabs(self.ez_all - tmpmed_all)
        mad_all = np.median(tmpx_all)
        sigma_mad_all = mad_all * 1.4826
        return sigma_mad_all

# %% [markdown]
# ### plot_old_valid

# %%
def plot_old_valid(photoz, ztrue,title, gals=None, colors=None, code="",path_to_save=''):
    """Plot traditional Zphot X Zspec and N(z) plots for illustration
    Ancillary function to be used by class Sample.

    Parameters
    ----------
    gals: `list`, (optional)
        list of galaxies' indexes
    colors: `list`, (optional)
        list of HTML codes for colors used in the plot highlighted points
    """
    df = pd.DataFrame({'z$_{true}$': ztrue,
                       'z$_{phot}$': photoz})
    fig = plt.figure(figsize=(10, 4), dpi=100)
    #fig.suptitle(name, fontsize=16)
    ax = plt.subplot(121)
    # sns.jointplot(data=df, x='z$_{true}$', y='z$_{phot}$', kind="kde")
    plt.plot(ztrue, photoz, 'k,', label=code)
    leg = ax.legend(fancybox=True, handlelength=0, handletextpad=0, loc="upper left")
    for item in leg.legendHandles:
        item.set_visible(False)
    if gals:
        if not colors:
            colors = ['r'] * len(gals)
        for i, gal in enumerate(gals):
            plt.plot(ztrue[gal], photoz[gal], 'o', color=colors[i], label=f'Galaxy {gal}')

    plt.plot(ztrue,ztrue,'r--', linewidth =0.5,alpha=0.4)
    zmax = np.max(ztrue) * 1.01
    plt.xlim(0, zmax)
    plt.ylim(0, zmax)
    plt.xlabel('z$_{true}$')
    plt.ylabel('z$_{phot}$')
    plt.subplot(122)
    sns.kdeplot(ztrue, shade=True, label='z$_{true}$',bw_adjust=0.3)
    sns.kdeplot(photoz, shade=True, label='z$_{phot}$',bw_adjust=0.3)
    plt.xlim(0, zmax)
    plt.xlabel('z')
    plt.legend()
    plt.suptitle(title)
    plt.tight_layout()
    if path_to_save !='':
        plt.savefig(path_to_save)

# %% [markdown]
# ### plot_metrics

# %%
def plot_metrics(zspec,
                 zphot,
                 maximum,
                 path_to_save='',
                 title=None,
                 initial=0):
    
    '''
    Function to plot Bias, Sigma_68, Out2σ, Out3σ given a spectroscopic and photometric redshift. 
    
    Args:
    
    zspec: Numpy array with the spectroscopic redshift.
    
    zphot: Numpy array with the photometric redshifts calculated. Same size as zspec.
    
    maximum: Float that indicates the redshift max of the plots.
    
    Kwargs:
    
    initial: Float that indicates the redshift min of the plots.
    
    
    
    '''
    
    
    
    
    
    
    bins = np.arange(initial, maximum, 0.1)
    points = bins+0.05
    fraction_outliers = []
    sigma68z = []
    sigmaz=[]
    meanz = []
    outliers_2 = []

    for index in range(len(bins) - 1):
        bin_lower = bins[index]
        bin_upper = bins[index + 1]
        
    
        values_r = zphot[(zphot >= bin_lower) & (zphot <= bin_upper)]
        values_s = zspec[(zphot >= bin_lower) & (zphot <= bin_upper)]
        
        

        deltabias = (values_r - values_s)
        mean_bias = np.mean(deltabias)  # Mean bias for each bin
        meanz.append(mean_bias)
        
        
    
        s = np.sort(np.abs(deltabias/(1+values_s)))  # Standard deviation (sigma) for each bin
        sigma68 = s[int(len(s)*0.68)]
        sigma68z.append(sigma68)
        
        
        
        sigma = (np.sum((values_r-values_s-mean_bias)**2)/len(values_r))**0.5
        sigmaz.append(sigma)
    
        # Calculate the fraction of outliers outside 3 sigma
        outliers = deltabias[np.abs(deltabias-mean_bias) > 3 * sigma]
        fraction_outlier = len(outliers) / len(deltabias)
        fraction_outliers.append(fraction_outlier)
        
        
    
        #2 sigma
        outliers2 = deltabias[np.abs(deltabias-mean_bias) > 2 * sigma]
        fraction_outlier2 = len(outliers2) / len(deltabias)
        outliers_2.append(fraction_outlier2)



    fig, axes = plt.subplots(4, 1, figsize=(8, 14), sharex=True)
    plt.subplots_adjust(hspace=0.001) 


    x_lim = (0, np.max(bins))

    # Subplot 1: Mean Bias
    axes[0].plot(points[:-1], meanz, 'bo-')
    axes[0].axhline(0, color='black', linestyle='--')
    axes[0].set_ylabel(r'$\Delta z$', fontsize=20)
    axes[0].set_xlim(x_lim)
    axes[0].tick_params(axis='both', labelsize=14)
    axes[0].grid(True)

    # Subplot 2: Sigma 68
    axes[1].plot(points[:-1], sigma68z, 'go-')
    axes[1].set_ylabel(r'$\sigma_{68}$', fontsize=20)
    axes[1].set_xlim(x_lim)
    #axes[1].axhline(0.12, color='black', linestyle='--')
    #axes[1].set_ylim(0,max(sigmaz))
    axes[1].set_ylim(0, 0.02)
    #axes[1].set_yticks(np.arange(0, 0.5, 0.05))
    axes[1].tick_params(axis='both', labelsize=14)
    axes[1].grid(True)


    # Subplot3: 2_outliers
    axes[2].plot(points[:-1],outliers_2,'o-',color='darkorange')
    #axes[2].set_xlabel(r'$Z_{phot}$', fontsize=20)
    axes[2].set_ylabel('out$_{2σ}$', fontsize=20)
    axes[2].set_xlim(x_lim)
    #axes[2].set_ylim(0,max(outliers_2)+0.01)
    axes[2].axhline(0.1, color='black', linestyle='--')
    axes[2].tick_params(axis='both', labelsize=14)
    axes[2].grid(True)
    axes[2].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))

    # Subplot 4: 3_outliers
    axes[3].plot(points[:-1], fraction_outliers, 'ro-')
    axes[3].set_xlabel(r'$Z_{phot}$', fontsize=20)
    axes[3].set_ylabel('out$_{3σ}$', fontsize=20)
    axes[3].set_xlim(x_lim)
    axes[3].set_ylim(0,max(fraction_outliers)+0.01)
    axes[3].axhline(0.015, color='black', linestyle='--')
    axes[3].tick_params(axis='both', labelsize=14)
    axes[3].grid(True)
   

    plt.suptitle(title)
    plt.xlim(0,3)#points[-1])
    plt.tight_layout()

    if path_to_save != '':
        plt.savefig(f'{path_to_save}')
    

    plt.show()

# %% [markdown]
# ### plot_scatter

# %%
def plot_scatter(zspec,zphot,catalog):
    kde = gaussian_kde([zspec, zphot])

    x_min, x_max = min(zspec), max(zspec)
    y_min, y_max = min(zphot), max(zphot)
    
    x, y = np.meshgrid(np.linspace(x_min, x_max, 100), np.linspace(y_min, y_max, 100))
    z = kde(np.vstack([x.ravel(), y.ravel()]))
    plt.figure(figsize=(8,6))


    plt.plot(zspec,zspec,'r--', linewidth =0.5)


    plt.contourf(x, y, z.reshape(x.shape), cmap='turbo', levels=100)
    colorbar = plt.colorbar()
    colorbar.set_label('Density', fontsize=20)

    plt.xlim(min(zphot), max(zphot))
    plt.ylim(min(zphot), max(zphot))
    plt.title(f'FzBoost_{catalog}')

    plt.xlabel(r'$z_{spec}$', fontsize=22)
    plt.ylabel(r'$z_{phot}$',fontsize=22)

    plt.xticks(fontsize=14)  
    plt.yticks(fontsize=14)


    plt.show()

# %% [markdown]
# ### plot_pit_qq

# %%
def plot_pit_qq(pdfs, zgrid, ztrue, bins=None, title=None, code=None,
                show_pit=True, show_qq=True,
                pit_out_rate=None, savefig=False) -> str:
    """Quantile-quantile plot
    Ancillary function to be used by class Metrics.

    Parameters
    ----------
    pit: `PIT` object
        class from metrics.py
    bins: `int`, optional
        number of PIT bins
        if None, use the same number of quantiles (sample.n_quant)
    title: `str`, optional
        if None, use formatted sample's name (sample.name)
    label: `str`, optional
        if None, use formatted code's name (sample.code)
    show_pit: `bool`, optional
        include PIT histogram (default=True)
    show_qq: `bool`, optional
        include QQ plot (default=True)
    pit_out_rate: `ndarray`, optional
        print metric value on the plot panel (default=None)
    savefig: `bool`, optional
        save plot in .png file (default=False)
    """

    if bins is None:
        bins = 100
    if title is None:
        title = ""

    if code is None:
        code = ""
        label = ""
    else:
        label = code + "\n"


    if pit_out_rate is not None:
        try:
            label += "PIT$_{out}$: "
            label += f"{float(pit_out_rate):.4f}"
        except:
            print("Unsupported format for pit_out_rate.")

    plt.figure(figsize=[4, 5])
    gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1])
    ax0 = plt.subplot(gs[0])
    sample = Sample(pdfs, zgrid, ztrue)

    if show_qq:
        ax0.plot(sample.qq[0], sample.qq[1], c='r',
                 linestyle='-', linewidth=3, label=label)
        ax0.plot([0, 1], [0, 1], color='k', linestyle='--', linewidth=2)
        ax0.set_ylabel("Q$_{data}$", fontsize=18)
        plt.ylim(-0.001, 1.001)
    plt.xlim(-0.001, 1.001)
    plt.title(title)
    if show_pit:
        fzdata = Ensemble(interp, data=dict(xvals=zgrid, yvals=pdfs))
        pitobj = PIT(fzdata, ztrue)
        pit_vals = np.array(pitobj.pit_samps)
        pit_out_rate = pitobj.evaluate_PIT_outlier_rate()

        try:
            y_uni = float(len(pit_vals)) / float(bins)
        except:
            y_uni = float(len(pit_vals)) / float(len(bins))
        if not show_qq:
            ax0.hist(pit_vals, bins=bins, alpha=0.7, label=label)
            ax0.set_ylabel('Number')
            ax0.hlines(y_uni, xmin=0, xmax=1, color='k')
            plt.ylim(0, )  # -0.001, 1.001)
        else:
            ax1 = ax0.twinx()
            ax1.hist(pit_vals, bins=bins, alpha=0.7)
            ax1.set_ylabel('Number')
            ax1.hlines(y_uni, xmin=0, xmax=1, color='k')
    leg = ax0.legend(handlelength=0, handletextpad=0, fancybox=True)
    for item in leg.legendHandles:
        item.set_visible(False)
    if show_qq:
        ax2 = plt.subplot(gs[1])
        ax2.plot(sample.qq[0], (sample.qq[1] - sample.qq[0]), c='r', linestyle='-', linewidth=3)
        plt.ylabel("$\Delta$Q", fontsize=18)
        ax2.plot([0, 1], [0, 0], color='k', linestyle='--', linewidth=2)
        plt.xlim(-0.001, 1.001)
        plt.ylim(np.min([-0.12, np.min(sample.qq[1] - sample.qq[0]) * 1.05]),
                 np.max([0.12, np.max(sample.qq[1] - sample.qq[0]) * 1.05]))
    if show_pit:
        if show_qq:
            plt.xlabel("Q$_{theory}$ / PIT Value", fontsize=18)
        else:
            plt.xlabel("PIT Value", fontsize=18)
    else:
        if show_qq:
            plt.xlabel("Q$_{theory}$", fontsize=18)
    if savefig:
        fig_filename = str("plot_pit_qq_" +
                           f"{(code).replace(' ', '_')}.png")
        plt.savefig(fig_filename)
    else:
        fig_filename = None

    return fig_filename


class Sample(Ensemble):
    """ Expand qp.Ensemble to append true redshifts
    array, metadata, and specific plots. """

    def __init__(self, pdfs, zgrid, ztrue, photoz_mode=None, code="", name="", n_quant=100):
        """Class constructor

        Parameters
        ----------
        pdfs: `ndarray`
            photo-z PDFs array, shape=(Ngals, Nbins)
        zgrid: `ndarray`
            PDF bins centers, shape=(Nbins,)
        ztrue: `ndarray`
            true redshifts, shape=(Ngals,)
        photoz_mode: `ndarray`
            photo-z (PDF mode), shape=(Ngals,)
        code: `str`, (optional)
            algorithm name (for plot legends)
        name: `str`, (optional)
            sample name (for plot legends)
        """

        super().__init__(interp, data=dict(xvals=zgrid, yvals=pdfs))
        self._pdfs = pdfs
        self._zgrid = zgrid
        self._ztrue = ztrue
        self._photoz_mode = photoz_mode
        self._code = code
        self._name = name
        self._n_quant = n_quant
        self._pit = None
        self._qq = None


    @property
    def code(self):
        """Photo-z code/algorithm name"""
        return self._code

    @property
    def name(self):
        """Sample name"""
        return self._name

    @property
    def ztrue(self):
        """True redshifts array"""
        return self._ztrue

    @property
    def zgrid(self):
        """Redshift grid (binning)"""
        return self._zgrid

    @property
    def photoz_mode(self):
        """Photo-z (mode) array"""
        return self._photoz_mode

    @property
    def n_quant(self):
        return self._n_quant

    @property
    def pit(self):
        if self._pit is None:
            pit_array = np.array([self[i].cdf(self.ztrue[i])[0][0] for i in range(len(self))]) 
            self._pit = pit_array
        return self._pit

    @property
    def qq(self, n_quant=100):
        q_theory = np.linspace(0., 1., n_quant)
        q_data = np.quantile(self.pit, q_theory)
        self._qq = (q_theory, q_data)
        return self._qq

    def __len__(self):
        if len(self._ztrue) != len(self._pdfs):
            raise ValueError("Number of pdfs and true redshifts do not match!!!")
        return len(self._ztrue)

    def __str__(self):
        code_str = f'Algorithm: {self._code}'
        name_str = f'Sample: {self._name}'
        line_str = '-' * (max(len(code_str), len(name_str)))
        text = str(line_str + '\n' +
                   name_str + '\n' +
                   code_str + '\n' +
                   line_str + '\n' +
                   f'{len(self)} PDFs with {len(self.zgrid)} probabilities each \n' +
                   f'qp representation: {self.gen_class.name} \n' +
                   f'z grid: {len(self.zgrid)} z values from {np.min(self.zgrid)} to {np.max(self.zgrid)} inclusive')
        return text

# %% [markdown]
# ## Loading data and preparing for plots

# %%
mag=25.0

# %%
result = DS.read_file('pdfs_data', QPHandle, 
                          f'{path}/results/results_DP02_{fraction}_{reg}_i_{mag}.hdf5')()

# %%
############### True redshift #############
catalog = pd.read_hdf(f'{path}/samples/validation_DP02_i_{mag}.hdf5',key='data')
ztrue =  np.array(catalog['redshift'])

############### Max redshift ##############
z_max = result.build_tables()['meta']['xvals'][0][-1]

############ X values for plot ############
zgrid = np.linspace(0, z_max, 301)

################## PDFS ##################
pdfs = result.build_tables()['data']['yvals']

# %%
mean = result.mean()
#mode = result.mode(zgrid)

########## Median or mode of PDF ##########

zphot  = np.array([valor for sublista in mean for valor in sublista]) # Choose mode or mean

# %% [markdown]
# ## Plots

# %%
plot_old_valid(zphot,ztrue,'FzB_DC2_w10year')#,path_to_save=f'/home/iago/ic_cosmo/plots/i{mag}_scatter.png')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(14,7))
y = plt.hist(ztrue,bins=zgrid,label='Zspec', density=True)
t = plt.hist(zphot,bins=zgrid,label='Zphot', alpha=0.4, density=True,color='red')
#t = plt.hist(zphot_,bins=zgrid,label='Zphot_mixed', histtype = 'step', density=True)
plt.title('DC2 Normalized Redshift Histogram')
plt.xlabel('z')
#plt.xlim(0,1.4)
plt.legend()
#plt.savefig(f'/home/iago/ic_cosmo/plots/i{mag}_hist.png')

# %%
t = plt.hist(zphot,bins=zgrid,label='Zphot',alpha=0.5, color='red')
y = plt.hist(ztrue,bins=zgrid,label='Zspec',alpha=0.5, color='blue')
plt.legend()

# %%
plt.plot(zgrid[:-1],y[0]-t[0])

# %%
plt.plot(ztrue, zphot, 'k,')
plt.xlim(0,max(zphot))
plt.ylim(0,max(zphot))

plt.plot(zphot,zphot,'r--', linewidth =0.5,alpha=0.4)
plt.xlabel('z$_{true}$')
plt.ylabel('z$_{phot}$')
plt.title('DC2')
#plt.savefig(f'/home/iago/ic_cosmo/plots/i{mag}_scatter.png')
plt.show()

# %%
i=1
plt.figure(figsize=(8,8))
for band in bands:
    plt.subplot(3,2,i)
    plt.scatter(zphot-ztrue,catalog[f'mag_err_{band}_lsst'],s=0.3)
    plt.axvline(0.1, color='black')
    plt.axvline(-0.1, color='black')
    plt.title(band)
    plt.ylim(0,0.1)
    i+=1

# %%
plot_metrics(ztrue,zphot,2.6,initial=0,title='FzB_DC2_w10year')#,path_to_save=f'/home/iago/ic_cosmo/plots/metrics_i{mag}.png')

# %% [markdown]
# ## Studying the QQ plot
#
# I'm trying to discover why N(z) looks so good and the QQ plot looks not that good. The problem might be the function of the QQ plot.

# %%
t = Sample(pdfs,zgrid,ztrue)

# %%
pit_array = np.array([t[i].cdf(ztrue[i])[0][0] for i in range(len(t))])

# %%
pit_array
# Out:
# array([0.76077626, 0.82780552, 0.31627934, ..., 0.58957507, 0.54218056,
#        0.58665723])

# %%
index = 13
plt.plot(zgrid,pdfs[index])
plt.axvline(ztrue[index],color='red')
plt.xlim(0,0.5)
# Out:
# (0.0, 0.5)

# %%
plt.scatter(range(len(pit_array)),pit_array,s=1)

# %%
np.quantile(pit_array,np.linspace(0,1,100))
# Out:
# array([0.        , 0.14440046, 0.21419265, 0.25701445, 0.28946486,
#        0.31315535, 0.33301929, 0.35037485, 0.3672659 , 0.38231624,
#        0.3955739 , 0.40763668, 0.41761042, 0.42694832, 0.43666038,
#        0.44552817, 0.45371321, 0.46144406, 0.46829995, 0.47564159,
#        0.48200516, 0.48882142, 0.49474227, 0.50043769, 0.50538914,
#        0.51066476, 0.51551407, 0.52045216, 0.52548322, 0.53019047,
#        0.53490695, 0.53915402, 0.54369484, 0.54794221, 0.55247875,
#        0.55680496, 0.56100319, 0.56513422, 0.56894435, 0.57280817,
#        0.57669888, 0.5806385 , 0.584827  , 0.58854787, 0.59234799,
#        0.59597999, 0.60031788, 0.60383469, 0.60749651, 0.61122567,
#        0.61501974, 0.61881084, 0.62269926, 0.62676614, 0.63026404,
#        0.63429519, 0.63834477, 0.64202019, 0.64608629, 0.64988639,
#        0.65391682, 0.65789751, 0.66189023, 0.66567217, 0.66965827,
#        0.6739607 , 0.67830943, 0.68262401, 0.6870161 , 0.69159128,
#        0.69603942, 0.70059521, 0.70496494, 0.71023797, 0.71520066,
#        0.72047022, 0.72657739, 0.73210851, 0.73771449, 0.74327011,
#        0.74879411, 0.75477377, 0.76142082, 0.76814883, 0.77476228,
#        0.7819306 , 0.78963133, 0.7975105 , 0.80603256, 0.81509231,
#        0.82367277, 0.83406175, 0.84515009, 0.8584259 , 0.87422476,
#        0.89062936, 0.91029045, 0.93295966, 0.96352133, 1.        ])

# %% [markdown]
# ## Plot pit

# %%
plot_pit_qq(pdfs,zgrid,ztrue,title='FzB_DP02')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 plot_pit_qq(pdfs,zgrid,ztrue,title='FzB_DP02')
#
# Cell In[48], line 53, in plot_pit_qq(pdfs, zgrid, ztrue, bins, title, code, show_pit, show_qq, pit_out_rate, savefig)
#      50 sample = Sample(pdfs, zgrid, ztrue)
#      52 if show_qq:
# ---> 53     ax0.plot(sample.qq[0], sample.qq[1], c='r',
#      54              linestyle='-', linewidth=3, label=label)
#      55     ax0.plot([0, 1], [0, 1], color='k', linestyle='--', linewidth=2)
#      56     ax0.set_ylabel("Q$_{data}$", fontsize=18)
#
# Cell In[48], line 183, in Sample.qq(self, n_quant)
#     180 @property
#     181 def qq(self, n_quant=100):
#     182     q_theory = np.linspace(0., 1., n_quant)
# --> 183     q_data = np.quantile(self.pit, q_theory)
#     184     self._qq = (q_theory, q_data)
#     185     return self._qq
#
# Cell In[48], line 176, in Sample.pit(self)
#     173 @property
#     174 def pit(self):
#     175     if self._pit is None:
# --> 176         pit_array = np.array([self[i].cdf(self.ztrue[i])[0][0] for i in range(len(self))])
#     177         self._pit = pit_array
#     178     return self._pit
#
# File ~/miniforge3/envs/rail_env/lib/python3.12/site-packages/qp/ensemble.py:73, in Ensemble.__getitem__(self, key)
#      71 else:
#      72     ancil = None
# ---> 73 return Ensemble(self._gen_obj.create, data=red_data, ancil=ancil)
#
# File ~/miniforge3/envs/rail_env/lib/python3.12/site-packages/qp/ensemble.py:34, in Ensemble.__init__(self, gen_func, data, ancil)
#      32 #start_time = timeit.default_timer()
#      33 self._gen_func = gen_func
# ---> 34 self._frozen = self._gen_func(**data)
#      35 self._gen_obj = self._frozen.dist
#      36 self._gen_class = type(self._gen_obj)
#
# File ~/miniforge3/envs/rail_env/lib/python3.12/site-packages/qp/pdf_gen.py:136, in Pdf_gen.create(cls, **kwds)
#     133 """Create and return a `scipy.stats.rv_frozen` object using the
#     134 keyword arguemntets provided"""
#     135 # pylint: disable=not-callable
# --> 136 obj, kwds_freeze = cls.create_gen(**kwds)
#     137 return obj(**kwds_freeze)
#
# File ~/miniforge3/envs/rail_env/lib/python3.12/site-packages/qp/pdf_gen.py:349, in Pdf_rows_gen.create_gen(cls, **kwds)
#     345 @classmethod
#     346 def create_gen(cls, **kwds):
#     347     """Create and return a `scipy.stats.rv_continuous` object using the
#     348     keyword arguemntets provided"""
# --> 349     return (cls(**kwds), {})
#
# File ~/miniforge3/envs/rail_env/lib/python3.12/site-packages/qp/interp_pdf.py:77, in interp_gen.__init__(self, xvals, yvals, *args, **kwargs)
#      74 self._xmax = self._xvals[-1]
#      75 kwargs['shape'] = np.shape(yvals)[:-1]
# ---> 77 self._yvals = reshape_to_pdf_size(yvals, -1)
#      79 check_input = kwargs.pop('check_input', True)
#      80 if check_input:
#
# File ~/miniforge3/envs/rail_env/lib/python3.12/site-packages/qp/utils.py:842, in reshape_to_pdf_size(vals, split_dim)
#     827 """Reshape an array to match the number of PDFs in a distribution
#     828
#     829 Parameters
#    (...)
#     839     The reshaped array
#     840 """
#     841 in_shape = np.shape(vals)
# --> 842 npdf = np.product(in_shape[:split_dim]).astype(int)
#     843 per_pdf = in_shape[split_dim:]
#     844 out_shape = np.hstack([npdf, per_pdf])
#
# File ~/miniforge3/envs/rail_env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3845, in product(*args, **kwargs)
#    3832 @array_function_dispatch(_product_dispatcher, verify=False)
#    3833 def product(*args, **kwargs):
#    3834     """
#    3835     Return the product of array elements over a given axis.
#    3836
#    (...)
#    3843     prod : equivalent function; see for details.
#    3844     """
# -> 3845     return prod(*args, **kwargs)
#
# File ~/miniforge3/envs/rail_env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3100, in prod(a, axis, dtype, out, keepdims, initial, where)
#    2979 @array_function_dispatch(_prod_dispatcher)
#    2980 def prod(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2981          initial=np._NoValue, where=np._NoValue):
#    2982     """
#    2983     Return the product of array elements over a given axis.
#    2984
#    (...)
#    3098     10
#    3099     """
# -> 3100     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
#    3101                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/miniforge3/envs/rail_env/lib/python3.12/site-packages/numpy/core/fromnumeric.py:72, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      71 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
# ---> 72     passkwargs = {k: v for k, v in kwargs.items()
#      73                   if v is not np._NoValue}
#      75     if type(obj) is not mu.ndarray:
#      76         try:
#
# KeyboardInterrupt:

# %%
old_metrics_table(zphot,ztrue)
